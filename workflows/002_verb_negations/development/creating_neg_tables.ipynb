# %% [markdown]
# ## Creating negation tables

# %% [markdown]
# Creating a new database with two verb negation tables. The tables will be created from transactions (v32), where the main verb occurs in a negated form. Resulting tables include selected attributes from *transaction_head* and *transaction_row* tables that will be used in creating negation patterns.

# %%
import sys
sys.path.append('../../../common_code')

# %%
import sqlite3
from paths import PATH_ROOT
from db_operations.verb_transactions.neg_tables_creation import *
from db_operations.db_display import *

# %% [markdown]
# ## Input parameters

# %%
INPUT_DIR = "C:/Users/liivas/Documents/Töö/verbirektisoonid"

RESULT_DB = "neg_tables.db"
TRANSACTION_DB = f"{INPUT_DIR}/v32_data.db"

# %% [markdown]
# ## Data processing

# %%
con = sqlite3.connect(RESULT_DB)
cur = con.cursor()

cur.execute(f'ATTACH DATABASE "{TRANSACTION_DB}" AS transactions')

create_neg_tables(
    cur,
    transaction_head='transactions.transaction_head',
    transaction_row='transactions.transaction_row'
    )
con.close()

# %% [markdown]
# ## Result

# %%
display_sqlite_as_dataframe(RESULT_DB, 'verb_neg', 10)
# Out:
#     id     verb verb_compound      form     deprel  \
# 0   54    saama                     saa       root
# 1   60   tahtma                    taha       conj
# 2   63  õpetama                õpetanud       conj
# 3   74    saama                     saa      advcl
# 4   82   pidama                   peaks        aux
# 5   97    võtma                    võta  acl:relcl
# 6  101   oskama                    oska      advcl
# 7  120   pidama                   peaks        aux
# 8  121   minema           ära    läheks       conj
# 9  148   tundma                   tunne      advcl
#
#                            feats
# 0          aux,indic,neg,pres,ps
# 1  imper,main,neg,pres,ps,ps2,sg
# 2          impf,indic,mod,neg,ps
# 3   imper,mod,neg,pres,ps,ps2,sg
# 4           aux,cond,neg,pres,ps
# 5          aux,indic,neg,pres,ps
# 6          aux,indic,neg,pres,ps
# 7          cond,main,neg,pres,ps
# 8           aux,cond,neg,pres,ps
# 9   imper,mod,neg,pres,ps,ps2,sg

# %%
display_sqlite_as_dataframe(RESULT_DB, 'verb_neg_phrases', 10)
# Out:
#    head_id  loc  loc_rel deprel           form          lemma  \
# 0       54    3       -2  xcomp        rikkaks          rikas
# 1       54    4       -1    aux             ei             ei
# 2       60   10       -2  nsubj          nemad           tema
# 3       60   11       -1    aux             ei             ei
# 4       60   13        1  xcomp           olla          olema
# 5       60   14        2  xcomp     bussijuhid      bussijuht
# 6       63    7       -2  nsubj  ebastabiilsus  ebastabiilsus
# 7       63    8       -1    aux             on          olema
# 8       63   12        1  xcomp          elama          elama
# 9       74    2       -2  nsubj             sa           sina
#
#                          feats parent_loc pos
# 0                    pos,sg,tr       None   A
# 1                      aux,neg       None   V
# 2                       nom,pl       None   P
# 3                      aux,neg       None   V
# 4                     inf,main       None   V
# 5                   com,nom,pl       None   S
# 6                   com,nom,sg       None   S
# 7  af,aux,indic,pl,pres,ps,ps3       None   V
# 8               ill,mod,ps,sup       None   V
# 9                       nom,sg       None   P

# %% [markdown]
# ## Additional documentation

# %%
# ?create_neg_tables
