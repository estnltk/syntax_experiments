# %%
import os, sys, re
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
DATA_FILE = "../results/samples_for_simple_sentences_results_analyzed.csv"

# %%
df = pd.read_csv(DATA_FILE, sep=",", encoding="utf-8")

# A ja S n80 
n80 = df[(df["initial_cat"]=="a_n80") | (df["initial_cat"]=="s_n80")]

# A ja S n80, mis ei ole ELT
n80_noelt = n80[(n80["tag"]!= "E") & (n80["tag"]!= "L") & (n80["tag"]!= "T")  & ~(n80["tags"].str.contains("ELT", na=False))]
n80_noelt = n80_noelt[(~n80_noelt["verb_head_same_sent"].isna()) & (~n80_noelt["head_verbi_alluv"].isna())]

n80_noelt = n80_noelt[['sentence_id', 'head_id', 'head_loc', 'verb', 'verb_compound',
       'morph_case', 'lemma', 'form', 'sentence', 'simple_sentences_gpt4o', 'tags', 'tag',
       'initial_cat', 'verb_head_same_sent', 'head_verbi_alluv']]

# A ja S n80, mis on ELT
n80_elt = n80[(n80["tag"]== "E") | (n80["tag"]== "L") | (n80["tag"]== "T")  | (n80["tags"].str.contains("ELT", na=False))]
n80_elt = n80_elt[(~n80_elt["verb_head_same_sent"].isna()) & (~n80_elt["head_verbi_alluv"].isna())]

n80_elt = n80_elt[['sentence_id', 'head_id', 'head_loc', 'verb', 'verb_compound',
       'morph_case', 'lemma', 'form', 'sentence', 'simple_sentences_gpt4o', 'tags', 'tag',
       'initial_cat', 'verb_head_same_sent', 'head_verbi_alluv']]

# %% [markdown]
# # Kokkuvõte A ja S n80, mis ei ole E/L/T (100 näidet)

# %%
same_sent = n80_noelt[n80_noelt["verb_head_same_sent"]=="y"]
not_same_sent = n80_noelt[n80_noelt["verb_head_same_sent"]=="n"]
not_same_but_error = not_same_sent[not_same_sent["head_verbi_alluv"]=="?"]
not_same_not_alluv = not_same_sent[not_same_sent["head_verbi_alluv"]=="n"]
not_same_orig_error =  not_same_sent[not_same_sent["head_verbi_alluv"]=="e"]
same_sent_alluv = same_sent[same_sent["head_verbi_alluv"]=="y"]
same_sent_replaced = same_sent[same_sent["head_verbi_alluv"]=="?"]
same_sent_kesksona = same_sent[same_sent["head_verbi_alluv"]=="k"]
same_sent_error = same_sent[same_sent["head_verbi_alluv"]=="e"]
#errors = n80_noelt[n80_noelt["verb_head_same_sent"]=="e"]
gpt_errors = n80_noelt[n80_noelt["verb_head_same_sent"]=="?"]

# %%
print("verb + peasõna on samas lihtlauses: ", len(same_sent))
print("verb+ps samas lihtlauses ja ps on verbi alluv: ", len(same_sent_alluv), "/", len(same_sent))
print("verb+ps samas lihtlauses aga peasõna on asendatud teise sõnaga (enamasti sisuliselt õige): ", len(same_sent_replaced), "/", len(same_sent))
print("verb+ps samas lihtlauses aga orig lauses kesksõna vorm: ", len(same_sent_kesksona), "/", len(same_sent))
print("verb+ps samas lihtlauses aga lauses probleem: ", len(same_sent_error), "/", len(same_sent))


print("\n")

print("verb + peasõna pole samas lihtlauses: ", len(not_same_sent))
print("verb+ps pole samas lihtlauses aga orig lauses on ps verbi alluv (gpt lausestamise viga):", len(not_same_but_error), "/", len(not_same_sent) )
print("verb+ps pole samas lihtlauses ja ps ei ole orig lauses verbi alluv:", len(not_same_not_alluv), "/", len(not_same_sent) )
print("verb+ps pole samas lihtlauses ja orig lauses midagi valesti:", len(not_same_orig_error), "/", len(not_same_sent) )

print("\n")

#print("peasõna süntaksi viga:", len(errors))
print("gpt lausestamisega muutus struktuur liiga palju:", len(gpt_errors))
# Out:
# verb + peasõna on samas lihtlauses:  86
# verb+ps samas lihtlauses ja ps on verbi alluv:  70 / 86
# verb+ps samas lihtlauses aga peasõna on asendatud teise sõnaga (enamasti sisuliselt õige):  4 / 86
# verb+ps samas lihtlauses aga orig lauses kesksõna vorm:  8 / 86
# verb+ps samas lihtlauses aga lauses probleem:  4 / 86
#
#
# verb + peasõna pole samas lihtlauses:  7
# verb+ps pole samas lihtlauses aga orig lauses on ps verbi alluv (gpt lausestamise viga): 4 / 7
# verb+ps pole samas lihtlauses ja ps ei ole orig lauses verbi alluv: 0 / 7
# verb+ps pole samas lihtlauses ja orig lauses midagi valesti: 3 / 7
#
#
# gpt lausestamisega muutus struktuur liiga palju: 2

# %%
not_same_sent
# Out:
#      sentence_id   head_id  head_loc           verb verb_compound morph_case  \
# 235      4020416   6471584        20         lugema           NaN        all
# 245      2342833   3753052         2  kompenseerima           NaN        all
# 246      2970206   4764348         3          kütma           NaN        all
# 256      2737810   4391255        13         lugema           NaN        all
# 258     10820295  17329943         8         mõjuma           NaN        all
# 776     16334815  25281664        61         surema           NaN       adit
# 791      1163886   1849246         9         surema           NaN       adit
#
#           lemma            form  \
# 235  valijamees  valijameestele
# 245      seadus       seadusele
# 246        tema           neile
# 256      nooruk       noorukile
# 258   diplomaat    diplomaadile
# 776  kanza-surm     kanza-surma
# 791   kopsuvähk      kopsuvähki
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   sentence  \
# 235                                                                                                                                                                                                                                                                                                                                                                                                                          Tehtud on Eesti poliitilises kultuuris pretsedenditu erakondlik kampaaniareis Pärnumaale , kus Rahvaliit presidendi hõlma varjust omavalitsustele ( loe : valijameestele ) rahamägesid ja eurojõgesid lubas .
# 245                                                                                                                                                                                                                                                                                                                                                                                                                                              Vastavalt seadusele kompenseerib kohalik omavalitsus investeeringud teedeehitusse , drenaaži ja tänavavalgutusse , juhul kui need on avalikus kasutuses või kui ei lepita kokku teisiti .
# 246                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        " Kütsime neile sauna ka rõivistusse , " muheles Aivar Pohlak .
# 256                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Tartus Võru tänaval kinnipeetud Audi 80 roolis istunud 1987 aastal sündinud pimedale noorukile luges kaarti kõrvalistuja , kel samuti puudus juhiluba .
# 258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   “ Postimehe ” arvates mõjub Venemaa suursaadiku diplomaadile kohatu üliaktiivsus meedia õpetamisel Eesti-Vene niigi habrastele suhetele pärssivalt .
# 776  niisiis , uurisin antud linki sealt lehelt veel linke ja otsisin veel täiendust ja sain päris palju teada selle asja kohta : esiteks final fantasy sulle teadmiseks et alkohol seejärel tubakas on palju ohtlikumad ja suuremat sõltuvust tekitavad asjad kui kanza ( kanep tekitab vähem sõltuvust kui kohvi ntx ) , kanepiga pole võimalik üledoosi kätte surra , keegi pole kanza-surma surnud , kanza ei tekita inimeses vastupidiselt ntx muudele narkodele ja alcole vägivallatunnet , pigem rahulikku ja mõnusa olemise ( nagu mõne pilsneri joomine ) , kanza on paljus mõttes kasulik ( saab teha köit , ravimina jnejne . )
# 791                                                                                                                                                                                                                                                                                                                                                                                                       Nädal tagasi suri 61. eluaastal oma kodus Fairfaxis kopsuvähki Michaela Odone , kelle katsed leida ravimit oma poja raske päriliku haiguse vastu said aluseks Eestigi telekanaleil mitu korda näidatud filmile " Lorenzo õli " .
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   simple_sentences_gpt4o  \
# 235                                                                                                                                                                                                                                                                                                                                    ['Tehtud on erakondlik kampaaniareis Pärnumaale.', 'See on pretsedenditu Eesti poliitilises kultuuris.', 'Rahvaliit lubas presidendi hõlma varjust omavalitsustele rahamägesid ja eurojõgesid.', 'Omavalitsused on valijamehed.']
# 245                                                                                                                                                                                                                                                                               ['Seadus sätestab kohaliku omavalitsuse kohustused.', 'Kohalik omavalitsus kompenseerib investeeringud teedeehitusse, drenaaži ja tänavavalgustusse.', 'Kompensatsioon toimub juhul, kui need on avalikus kasutuses.', 'Kompensatsioon toimub ka juhul, kui ei lepita kokku teisiti.']
# 246                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['Aivar Pohlak muheles.', 'Aivar Pohlak ütles, et nad kütsid sauna rõivistusse.']
# 256                                                                                                                                                                                                                                                                                                                                                                                  ['Politsei pidas Tartus Võru tänaval kinni Audi 80.', 'Audi 80 roolis istus 1987. aastal sündinud pime nooruk.', 'Kaarti luges kõrvalistuja.', 'Ka kõrvalistujal puudus juhiluba.']
# 258                                                                                                                                                                                                                                                                                                                                                                                        ['“Postimees” avaldas arvamuse.', 'Venemaa suursaadiku üliaktiivsus meedia õpetamisel on diplomaadile kohatu.', 'See mõjub Eesti-Vene niigi habrastele suhetele pärssivalt.']
# 776  ['Uurisin antud linki.', 'Leidsin sealt lehelt veel linke.', 'Otsisin veel täiendust.', 'Sain päris palju teada selle asja kohta.', 'Final Fantasy, sulle teadmiseks, et alkohol ja tubakas on palju ohtlikumad kui kanep.', 'Kanep tekitab vähem sõltuvust kui kohv.', 'Kanepiga pole võimalik üledoosi kätte surra.', 'Keegi pole kanepitarbimise tõttu surnud.', 'Kanep ei tekita inimeses vägivallatunnet.', 'Kanep tekitab pigem rahuliku ja mõnusa olemise.', 'Kanep on paljus mõttes kasulik.', 'Kanepist saab teha köit.', 'Kanepit kasutatakse ravimina.']
# 791                                                                                                                                                                                                                                                                ['Michaela Odone suri nädal tagasi.', 'Ta suri 61. eluaastal.', 'Ta suri oma kodus Fairfaxis.', 'Surma põhjus oli kopsuvähk.', 'Michaela Odone otsis ravimit oma poja raske päriliku haiguse vastu.', 'Need katsed said aluseks filmile "Lorenzo õli".', 'Filmi on näidatud ka Eesti telekanalitel.']
#
#                             tags  tag initial_cat verb_head_same_sent  \
# 235  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   n
# 245                          NaN  NaN       a_n80                   n
# 246                          NaN    A       a_n80                   n
# 256  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   n
# 258                          NaN    A       a_n80                   n
# 776                          NaN  NaN       s_n80                   n
# 791         |S|AS|LS|ST|AST|LST|  NaN       s_n80                   n
#
#     head_verbi_alluv
# 235                e
# 245                e
# 246                ?
# 256                ?
# 258                e
# 776                ?
# 791                ?

# %%
not_same_but_error
# Out:
#      sentence_id   head_id  head_loc    verb verb_compound morph_case  \
# 246      2970206   4764348         3   kütma           NaN        all
# 256      2737810   4391255        13  lugema           NaN        all
# 776     16334815  25281664        61  surema           NaN       adit
# 791      1163886   1849246         9  surema           NaN       adit
#
#           lemma         form  \
# 246        tema        neile
# 256      nooruk    noorukile
# 776  kanza-surm  kanza-surma
# 791   kopsuvähk   kopsuvähki
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   sentence  \
# 246                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        " Kütsime neile sauna ka rõivistusse , " muheles Aivar Pohlak .
# 256                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Tartus Võru tänaval kinnipeetud Audi 80 roolis istunud 1987 aastal sündinud pimedale noorukile luges kaarti kõrvalistuja , kel samuti puudus juhiluba .
# 776  niisiis , uurisin antud linki sealt lehelt veel linke ja otsisin veel täiendust ja sain päris palju teada selle asja kohta : esiteks final fantasy sulle teadmiseks et alkohol seejärel tubakas on palju ohtlikumad ja suuremat sõltuvust tekitavad asjad kui kanza ( kanep tekitab vähem sõltuvust kui kohvi ntx ) , kanepiga pole võimalik üledoosi kätte surra , keegi pole kanza-surma surnud , kanza ei tekita inimeses vastupidiselt ntx muudele narkodele ja alcole vägivallatunnet , pigem rahulikku ja mõnusa olemise ( nagu mõne pilsneri joomine ) , kanza on paljus mõttes kasulik ( saab teha köit , ravimina jnejne . )
# 791                                                                                                                                                                                                                                                                                                                                                                                                       Nädal tagasi suri 61. eluaastal oma kodus Fairfaxis kopsuvähki Michaela Odone , kelle katsed leida ravimit oma poja raske päriliku haiguse vastu said aluseks Eestigi telekanaleil mitu korda näidatud filmile " Lorenzo õli " .
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   simple_sentences_gpt4o  \
# 246                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['Aivar Pohlak muheles.', 'Aivar Pohlak ütles, et nad kütsid sauna rõivistusse.']
# 256                                                                                                                                                                                                                                                                                                                                                                                  ['Politsei pidas Tartus Võru tänaval kinni Audi 80.', 'Audi 80 roolis istus 1987. aastal sündinud pime nooruk.', 'Kaarti luges kõrvalistuja.', 'Ka kõrvalistujal puudus juhiluba.']
# 776  ['Uurisin antud linki.', 'Leidsin sealt lehelt veel linke.', 'Otsisin veel täiendust.', 'Sain päris palju teada selle asja kohta.', 'Final Fantasy, sulle teadmiseks, et alkohol ja tubakas on palju ohtlikumad kui kanep.', 'Kanep tekitab vähem sõltuvust kui kohv.', 'Kanepiga pole võimalik üledoosi kätte surra.', 'Keegi pole kanepitarbimise tõttu surnud.', 'Kanep ei tekita inimeses vägivallatunnet.', 'Kanep tekitab pigem rahuliku ja mõnusa olemise.', 'Kanep on paljus mõttes kasulik.', 'Kanepist saab teha köit.', 'Kanepit kasutatakse ravimina.']
# 791                                                                                                                                                                                                                                                                ['Michaela Odone suri nädal tagasi.', 'Ta suri 61. eluaastal.', 'Ta suri oma kodus Fairfaxis.', 'Surma põhjus oli kopsuvähk.', 'Michaela Odone otsis ravimit oma poja raske päriliku haiguse vastu.', 'Need katsed said aluseks filmile "Lorenzo õli".', 'Filmi on näidatud ka Eesti telekanalitel.']
#
#                             tags  tag initial_cat verb_head_same_sent  \
# 246                          NaN    A       a_n80                   n
# 256  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   n
# 776                          NaN  NaN       s_n80                   n
# 791         |S|AS|LS|ST|AST|LST|  NaN       s_n80                   n
#
#     head_verbi_alluv
# 246                ?
# 256                ?
# 776                ?
# 791                ?

# %%
not_same_not_alluv
# Out:
# Empty DataFrame
# Columns: [sentence_id, head_id, head_loc, verb, verb_compound, morph_case, lemma, form, sentence, simple_sentences_gpt4o, tags, tag, initial_cat, verb_head_same_sent, head_verbi_alluv]
# Index: []

# %%
not_same_orig_error
# Out:
#      sentence_id   head_id  head_loc           verb verb_compound morph_case  \
# 235      4020416   6471584        20         lugema           NaN        all
# 245      2342833   3753052         2  kompenseerima           NaN        all
# 258     10820295  17329943         8         mõjuma           NaN        all
#
#           lemma            form  \
# 235  valijamees  valijameestele
# 245      seadus       seadusele
# 258   diplomaat    diplomaadile
#
#                                                                                                                                                                                                           sentence  \
# 235  Tehtud on Eesti poliitilises kultuuris pretsedenditu erakondlik kampaaniareis Pärnumaale , kus Rahvaliit presidendi hõlma varjust omavalitsustele ( loe : valijameestele ) rahamägesid ja eurojõgesid lubas .
# 245                      Vastavalt seadusele kompenseerib kohalik omavalitsus investeeringud teedeehitusse , drenaaži ja tänavavalgutusse , juhul kui need on avalikus kasutuses või kui ei lepita kokku teisiti .
# 258                                                           “ Postimehe ” arvates mõjub Venemaa suursaadiku diplomaadile kohatu üliaktiivsus meedia õpetamisel Eesti-Vene niigi habrastele suhetele pärssivalt .
#
#                                                                                                                                                                                                                                                                      simple_sentences_gpt4o  \
# 235                                                       ['Tehtud on erakondlik kampaaniareis Pärnumaale.', 'See on pretsedenditu Eesti poliitilises kultuuris.', 'Rahvaliit lubas presidendi hõlma varjust omavalitsustele rahamägesid ja eurojõgesid.', 'Omavalitsused on valijamehed.']
# 245  ['Seadus sätestab kohaliku omavalitsuse kohustused.', 'Kohalik omavalitsus kompenseerib investeeringud teedeehitusse, drenaaži ja tänavavalgustusse.', 'Kompensatsioon toimub juhul, kui need on avalikus kasutuses.', 'Kompensatsioon toimub ka juhul, kui ei lepita kokku teisiti.']
# 258                                                                                                           ['“Postimees” avaldas arvamuse.', 'Venemaa suursaadiku üliaktiivsus meedia õpetamisel on diplomaadile kohatu.', 'See mõjub Eesti-Vene niigi habrastele suhetele pärssivalt.']
#
#                             tags  tag initial_cat verb_head_same_sent  \
# 235  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   n
# 245                          NaN  NaN       a_n80                   n
# 258                          NaN    A       a_n80                   n
#
#     head_verbi_alluv
# 235                e
# 245                e
# 258                e

# %%
same_sent.sample(5)
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 232      2544269   4081815        32      sõitma          otsa        all
# 201      3030028   4860257        10  põhjustama           NaN        all
# 261      1536015   2444551         8     eeldama           NaN        abl
# 262      9538320  15310475        11   helistama           NaN        all
# 795     15931669  24783119         1      põdema           NaN       adit
#
#          lemma          form  \
# 232     Rudolf     Rudolfile
# 201  maaomanik  maaomanikele
# 261  Hansapank  Hansapangalt
# 262   Frishman   Frishmanile
# 795  maksavähk    Maksavähki
#
#                                                                                                                                                                                                                      sentence  \
# 232  22.10.2002 kella 10.30 ajal juhtus Pärnus Karja ja Hõbeda tänava ristmikul liiklusõnnetus , kus sõiduauto Opel Omega , mida juhtis Martti ( s. 1968 ) sõitis otsa ülekäigurajal tänavat ületanud Rudolfile ( s. 1926 ) .
# 201                                                                                                Firma peab hüvitiste maksmist õigeks , kuna infrastruktuuriettevõtted põhjustavad maaomanikele kitsendusi ja ebamugavusi .
# 261                                                                                     Danil märkis , et antud hinnatase eeldab Hansapangalt juba suhteliselt suurt arengut , seda põhiliselt Läti ja Leedu pangandusturul .
# 262                                                                       Fraktsiooni Meie Valik esimees Tatjana Muravjova ütles : “ Olen Frishmanile korduvalt helistanud ja tedaistungitele kutsunud , aga ta pole tulnud .
# 795                                                                                                                                                   Maksavähki põdenud 56-aastane Meyer-Wölden suri esmaspäeval Münchenis .
#
#                                                                                                                                                                                                                                                                                      simple_sentences_gpt4o  \
# 232  ['22.10.2002 kella 10.30 ajal juhtus Pärnus liiklusõnnetus.', 'Õnnetus juhtus Karja ja Hõbeda tänava ristmikul.', 'Sõiduauto Opel Omega sõitis otsa ülekäigurajal tänavat ületanud Rudolfile.', 'Opel Omega juht oli Martti.', 'Martti on sündinud 1968. aastal.', 'Rudolf on sündinud 1926. aastal.']
# 201                                                                                                                                                                              ['Firma peab hüvitiste maksmist õigeks.', 'Infrastruktuuriettevõtted põhjustavad maaomanikele kitsendusi ja ebamugavusi.']
# 261                                                                                                                                                 ['Danil märkis midagi.', 'Antud hinnatase eeldab Hansapangalt suhteliselt suurt arengut.', 'See areng toimub põhiliselt Läti ja Leedu pangandusturul.']
# 262                                                     ['Tatjana Muravjova on fraktsiooni Meie Valik esimees.', 'Tatjana Muravjova ütles midagi.', 'Tatjana Muravjova on Frishmanile korduvalt helistanud.', 'Tatjana Muravjova on Frishmanit istungitele kutsunud.', 'Frishman pole istungitele tulnud.']
# 795                                                                                                                                                                                                             ['56-aastane Meyer-Wölden põdes maksavähki.', 'Ta suri esmaspäeval.', 'Ta suri Münchenis.']
#
#                             tags tag initial_cat verb_head_same_sent  \
# 232  |A|AE|AL|AS|AT|AET|ALT|AST|   A       a_n80                   y
# 201  |A|AE|AL|AS|AT|AET|ALT|AST|   A       a_n80                   y
# 261  |A|AE|AL|AS|AT|AET|ALT|AST|   A       a_n80                   y
# 262  |A|AE|AL|AS|AT|AET|ALT|AST|   A       a_n80                   y
# 795         |S|AS|LS|ST|AST|LST|   S       s_n80                   y
#
#     head_verbi_alluv
# 232                y
# 201                y
# 261                y
# 262                y
# 795                y

# %%
same_sent_alluv.sample(10)
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 770      9479129  15217805        20  haigestuma           NaN       adit
# 269     13520518  21624996         3       näima           NaN        all
# 226      7736111  12402767         7       andma           NaN        all
# 215      4284529   6893438         4   meenutama           NaN        all
# 213      8691290  13944108        13      laulma           NaN        all
# 212      3435614   5530981         2       näima           NaN        all
# 747      1139305   1810069        21      surema           NaN       adit
# 760      1201543   1910376        37      surema           NaN       adit
# 755     14186002  22551574        24      surema           NaN       adit
# 754      8819758  14164376         3      surema           NaN       adit
#
#                lemma                form  \
# 770     sapikivitõbi       sapikivitõppe
# 269         esindaja         esindajaile
# 226             Cave            Cave'ile
# 215          osaleja         osalejatele
# 213  kokkuhoidlikkus  kokkuhoidlikkusele
# 212         poliitik         poliitikule
# 747         süüfilis          süüfilisse
# 760        rasvumine          rasvumisse
# 755     suitsetamine       suitsetamisse
# 754         tardumus          tardumusse
#
#                                                                                                                                                                                                                                                                           sentence  \
# 770                                                                                                          Samasugune on haigestumus Põhjamaades , seevastu vaid kolm protsenti jaapanlastest ja tervelt 30-70 protsenti Põhja-Ameerika indiaanlastest haigestub sapikivitõppe .
# 269                                                                                                                                                                                      Teiste spordialade esindajaile näib , et tennisistide eskiis arvestab tennisistide huve .
# 226                                                   Idee tavatult roimarohke kauamängiva kokkupanekuks andis Cave'ile tema pikaaegne kaaskonspiraator ja kitarrist Blixa Bargeld pooleteise aasta eest , kui Cave & Bad Seeds salvestasid eelmist pikka plaati “ Let Love In ” .
# 215                                                                                                                                                         Konverentsi korraldajad meenutasid osalejatele , et Gaza sektori ja Palestiina humanitaarkriisist ei saa üle vaadata .
# 213                Selles paigas , kus hommikust õhtuni laulsid rohkem kui sada töötajat kiidulaulu kokkuhoidlikkusele , voorusele , harmooniale , korras seedimisele ja kodurahule , hõljus õhus finantstormide , intriigi , lahkhelide , seedehäirete ja abielurikkumise hõngu .
# 212                                                                                                                                                                Mõnele poliitikule näib lausa paradiisina , et ettevõtja peab oma maksumäära kinnitamiseks tema juurde tulema .
# 747                                                                                           Iiri kirjanik Oscar Wilde , kelle näidendid lahutavad publiku meelt ka sada aastat pärast autori surma , ei surnud mitte süüfilisse , vaid ajju levinud kroonilisse kõrvapõletikku .
# 760  Sama kahjulikult kui nälgimine mõjub mustlaskultuurile ja mõnedele islamimaadele omane pruudi nuumamine , mistõttu perekond sai küll naise eest väärilise hinna ( kehakaal väärismetalli kilodes vm ) , kuigi õnnetu pruut ise suri noorelt südame veresoonkonna rasvumisse .
# 755                          Polemiseerin teemal vaid nii palju , et umbes kuu aja eest oli kuskil portaalis uudis , et Eestis sureb iga päev viis inimest suitsetamisse , aga vahepeal pole olnud uudist , et suitsetamisse surijate arv oleks kahekordistunud ... aga mis tost .
# 754                                                                                                                                                                                                                                                  Inimkond sureb tardumusse ! ”
#
#                                                                                                                                                                                                                                                                                                              simple_sentences_gpt4o  \
# 770                                                                                                              ['Haigestumus sapikivitõppe on Põhjamaades samasugune kui mujal.', 'Sapikivitõppe haigestub vaid kolm protsenti jaapanlastest.', 'Sapikivitõppe haigestub tervelt 30–70 protsenti Põhja-Ameerika indiaanlastest.']
# 269                                                                                                                                                                                                                              ['Teiste spordialade esindajaile näib midagi.', 'Tennisistide eskiis arvestab tennisistide huve.']
# 226                                                                                   ["Blixa Bargeld andis Cave'ile idee kauamängiva kokkupanekuks.", "Blixa Bargeld on Cave'i pikaaegne kaaskonspiraator ja kitarrist.", 'See juhtus pooleteise aasta eest.', 'Cave & Bad Seeds salvestasid eelmist pikka plaati “Let Love In”.']
# 215                                                                                                                                                                              ['Konverentsi korraldajad meenutasid osalejatele midagi.', 'Nad meenutasid, et Gaza sektori ja Palestiina humanitaarkriisist ei saa üle vaadata.']
# 213                                                   ['Selles paigas laulsid hommikust õhtuni rohkem kui sada töötajat.', 'Töötajad laulsid kiidulaulu kokkuhoidlikkusele, voorusele, harmooniale, korras seedimisele ja kodurahule.', 'Õhus hõljus finantstormide, intriigi, lahkhelide, seedehäirete ja abielurikkumise hõngu.']
# 212                                                                                                                                                                                                  ['Mõnele poliitikule näib olukord lausa paradiisina.', 'Ettevõtja peab oma maksumäära kinnitamiseks poliitiku juurde tulema.']
# 747                                                                                                                         ['Iiri kirjanik Oscar Wilde lahutab oma näidenditega publiku meelt ka sada aastat pärast oma surma.', 'Oscar Wilde ei surnud süüfilisse.', 'Oscar Wilde suri ajju levinud kroonilisse kõrvapõletikku.']
# 760  ['Nälgimine mõjub mustlaskultuurile kahjulikult.', 'Nälgimine mõjub mõnedele islamimaadele omase pruudi nuumamise tõttu kahjulikult.', 'Perekond sai pruudi eest väärilise hinna.', 'Hind sõltus pruudi kehakaalust väärismetalli kilodes või muus mõõtühikus.', 'Õnnetu pruut suri noorelt südame veresoonkonna rasvumisse.']
# 755                                                                                                                                     ['Umbes kuu aja eest oli kuskil portaalis uudis, et Eestis sureb iga päev viis inimest suitsetamisse.', 'Vahepeal pole olnud uudist, et suitsetamisse surijate arv oleks kahekordistunud.']
# 754                                                                                                                                                                                                                                                                                                  ['Inimkond sureb tardumusse!']
#
#                             tags  tag initial_cat verb_head_same_sent  \
# 770         |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 269  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 226  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 215  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 213                          NaN  NaN       a_n80                   y
# 212  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 747         |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 760         |S|AS|LS|ST|AST|LST|    S       s_n80                   y
# 755                          NaN    S       s_n80                   y
# 754         |S|AS|LS|ST|AST|LST|    S       s_n80                   y
#
#     head_verbi_alluv
# 770                y
# 269                y
# 226                y
# 215                y
# 213                y
# 212                y
# 747                y
# 760                y
# 755                y
# 754                y

# %%
same_sent_replaced
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 237      7692281  12333295         5       näima           NaN        all
# 241      1892072   3014379        10       näima           NaN        all
# 264     15901007  24737765        17  kasseerima           NaN        abl
# 785       654720   1040331        19  haigestuma           NaN        ill
#
#           lemma          form  \
# 237  tantsuhitt  tantsuhitile
# 241         mis       millele
# 264   filmitäht   filmitähelt
# 785         see      sellesse
#
#                                                                                                                                                                   sentence  \
# 237                                                        Prince'i 1982. aastal ilmunud tantsuhitile “ 1999 ” näib aastavahetusega saabuvat uus ( ja oodatud ) tulemine .
# 241  Kuigi uus ajajärk võib meid eemale juhtida kuristikust , millele Eesti näis viimastel kuudel järjest kiiremini lähenevat , jäävad mitmed ohud endiselt õhku rippuma .
# 264                                     ( Muide , kui Brigitte Bardot'tuleb selle muhameedlase käest vett ostma , kasseerib kaupmees filmitähelt kahekümnekordse hinna ! )
# 785                  Ehkki rinnavähk ei ole Ameerika Ühendriikides naiste seas levinuim vähiliik ( esimesel kohal on kopsuvähk ) , haigestub sellesse iga päev 500 naist .
#
#                                                                                                                                                          simple_sentences_gpt4o  \
# 237                                       ["Prince'i tantsuhitt “1999” ilmus 1982. aastal.", 'Aastavahetusega näib saabuvat hittile uus tulemine.', 'See tulemine on oodatud.']
# 241  ['Uus ajajärk võib meid eemale juhtida kuristikust.', 'Eesti näis viimastel kuudel kuristikule järjest kiiremini lähenevat.', 'Mitmed ohud jäävad endiselt õhku rippuma.']
# 264                                              ['Brigitte Bardot tuleb selle muhameedlase käest vett ostma.', "Kaupmees kasseerib Brigitte Bardot'lt kahekümnekordse hinna."]
# 785                   ['Rinnavähk ei ole Ameerika Ühendriikides naiste seas levinuim vähiliik.', 'Levinuim vähiliik on kopsuvähk.', 'Iga päev haigestub rinnavähki 500 naist.']
#
#                             tags  tag initial_cat verb_head_same_sent  \
# 237                          NaN  NaN       a_n80                   y
# 241                          NaN  NaN       a_n80                   y
# 264  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 785                          NaN  NaN       s_n80                   y
#
#     head_verbi_alluv
# 237                ?
# 241                ?
# 264                ?
# 785                ?

# %%
same_sent_kesksona
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 739       938429   1494264        15      surema           NaN       adit
# 745     15015961  23555547         4  haigestuma           NaN        ill
# 749      7487923  12017641         4    nakatuma           NaN       adit
# 752      1090812   1733754         1  haigestuma           NaN       adit
# 753       806037   1286063         7      põdema           NaN       adit
# 786     16201132  25105865         5    nakatuma           NaN       adit
# 787      2514205   4031773         7      surema           NaN       adit
# 792     14206201  22586169         3    nakatuma           NaN       adit
#
#                     lemma                    form  \
# 739              marutõbi               marutõppe
# 745            seenhaigus          seenhaigusesse
# 749                  AIDS                   AIDSi
# 752             paragripp              Paragrippi
# 753               põletik               põletikku
# 786         viirusartriit          viirusartriiti
# 787            südametõbi             südametõppe
# 792  linnadžiibivaimustus  linnadžiibivaimustusse
#
#                                                                                                                                                                                                               sentence  \
# 739                                                                                              Pärtel ise tegi marutaudi süstikuuri läbi kümnekonna aasta eest , kui oli paljakäsi arstinud marutõppe surnud lehma .
# 745                                                                                    Peale selle võib seenhaigusesse haigestunud küünest nakkus levida ka haige teistele kehaosadele , eriti kätele ja kubemevolti .
# 749                                   “ Mitte ainult AIDSi nakatunud ei vaja kompleksravi : mujal maailmas lähtutakse põhimõttest , et sellega tuleb alustada nakatumise järel võimalikult ruttu , ” selgitab Raukas .
# 752                            Paragrippi haigestunud ja niisama nohus-köhas inimesed ostavad talvel tavapärasest rohkem vitamiine , aspiriini ning gripirohtusid , suurendades oluliselt ravimimüüjate sissetulekut .
# 753                                                                     Saunakuumust peaksid vältima epilepsia , peaaju põletikku põdenud ja kaugele arenenud veresoonkonna- , südame- ja neerupuudulikkusega haiged .
# 786                                                                                                                                       Maedi Visna'sse või kitsede viirusartriiti/-entsefaliiti nakatunud loomad on
# 787                                                       Kui küüniliselt mõelda , siis iga südametõppe surnud eduka maksumaksja näol kaotab linn võrreldamatult enam , kui oleks kulunud mõne palliplatsi loomiseks .
# 792  Ford tahab linnadžiibivaimustusse nakatunud Euroopas hiljemalt 2008. aastal müügile tuua väiksemat sorti nelikveolise universaalauto , millele loodetakse suuremat edu , kui praegune Maverick saavutada suutis .
#
#                                                                                                                                                                                                                                                                                                                                                   simple_sentences_gpt4o  \
# 739                                                                                                                                                                                                                                                  ['Pärtel tegi marutaudi süstikuuri läbi kümnekonna aasta eest.', 'Pärtel arstis paljakäsi marutõppe surnud lehma.']
# 745                                                                                                                                                                                                                  ['Seenhaigusesse haigestunud küünest võib nakkus levida haige teistele kehaosadele.', 'Nakkus levib eriti kätele.', 'Nakkus levib ka kubemevolti.']
# 749                                                                                                                                                                         ['Mitte ainult AIDSi nakatunud ei vaja kompleksravi.', 'Mujal maailmas lähtutakse põhimõttest, et kompleksravi tuleb alustada nakatumise järel võimalikult ruttu.', 'Raukas selgitab seda.']
# 752                                                                                            ['Paragrippi haigestunud inimesed ostavad talvel tavapärasest rohkem vitamiine, aspiriini ja gripirohtusid.', 'Nohus ja köhas inimesed ostavad talvel tavapärasest rohkem vitamiine, aspiriini ja gripirohtusid.', 'See suurendab oluliselt ravimimüüjate sissetulekut.']
# 753  ['Epilepsiahaiged peaksid vältima saunakuumust.', 'Peaaju põletikku põdenud haiged peaksid vältima saunakuumust.', 'Kaugele arenenud veresoonkonna puudulikkusega haiged peaksid vältima saunakuumust.', 'Kaugele arenenud südamepuudulikkusega haiged peaksid vältima saunakuumust.', 'Kaugele arenenud neerupuudulikkusega haiged peaksid vältima saunakuumust.']
# 786                                                                                                                                                                                                                                                                ["Maedi Visna'sse nakatunud loomad on.", 'Kitsede viirusartriiti/-entsefaliiti nakatunud loomad on.']
# 787                                                                                                                                                                                        ['Kui küüniliselt mõelda, siis linn kaotab iga südametõppe surnud eduka maksumaksja näol.', 'Kaotus on võrreldamatult suurem, kui oleks kulunud mõne palliplatsi loomiseks.']
# 792                                                                                                       ['Ford tahab Euroopas müügile tuua väiksemat sorti nelikveolise universaalauto.', 'Euroopa on nakatunud linnadžiibivaimustusse.', 'Ford plaanib seda teha hiljemalt 2008. aastal.', 'Ford loodab sellele autole suuremat edu kui praegune Maverick saavutas.']
#
#                      tags  tag initial_cat verb_head_same_sent  \
# 739  |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 745  |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 749  |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 752  |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 753  |S|AS|LS|ST|AST|LST|  NaN       s_n80                   y
# 786                   NaN  NaN       s_n80                   y
# 787                   NaN  NaN       s_n80                   y
# 792                   NaN    S       s_n80                   y
#
#     head_verbi_alluv
# 739                k
# 745                k
# 749                k
# 752                k
# 753                k
# 786                k
# 787                k
# 792                k

# %%
same_sent_error
# Out:
#      sentence_id   head_id  head_loc      verb verb_compound morph_case  \
# 207     17832366  27223743         8   kinkima           NaN        all
# 221      8969953  14421217         7  pressima         välja        abl
# 272      3900385   6282179         1   nähtuma          ette        all
# 773     15364971  23997877        11    surema           NaN       adit
#
#           lemma            form  \
# 207      arvuti        arvutile
# 221  kaubitseja  kaubitsejatelt
# 272    linnapea      Linnapeale
# 773        vang           vangi
#
#                                                                                                                                                                                                                                               sentence  \
# 207                                                                                                                                                                                                          ma ei kingi ju ventikat ka talle arvutile
# 221  Süüdistustelaine , et turu tegevjuhid pressivad kaubitsejatelt põhjendamatult palju raha välja ja kiusavad neid taga , tõusis taas päevakorda pärast detsembri lõpus toimunud pommiplahvatust , milles hukkus üks ja sai vigastada kolm inimest .
# 272                                                                                            Linnapeale , abilinnapeale , linnaosa vanematele ja linnasekretärile on ette nähtud 250 liitrit bensiini kuus , teistele autokasutajatele 200 liitrit .
# 773                                                                                          Usbekistanis Andijoni vanglas suri novembris piinamise tagajärjel kaks islamiäärmusluses süüdistatud vangi , ütlesid meeste sugulased ja inimõiguslased .
#
#                                                                                                                                                                                                                                                                                                                     simple_sentences_gpt4o  \
# 207                                                                                                                                                                                                                                                                                               ['Ma ei kingi ventikat talle arvutile.']
# 221  ['Turu tegevjuhte süüdistatakse kaubitsejatelt põhjendamatult palju raha välja pressimises.', 'Turu tegevjuhte süüdistatakse kaubitsejate tagakiusamises.', 'Süüdistused tõusid päevakorda pärast detsembri lõpus toimunud pommiplahvatust.', 'Pommiplahvatuses hukkus üks inimene.', 'Pommiplahvatuses sai vigastada kolm inimest.']
# 272              ['Linnapeale on ette nähtud 250 liitrit bensiini kuus.', 'Abilinnapeale on ette nähtud 250 liitrit bensiini kuus.', 'Linnaosa vanematele on ette nähtud 250 liitrit bensiini kuus.', 'Linnasekretärile on ette nähtud 250 liitrit bensiini kuus.', 'Teistele autokasutajatele on ette nähtud 200 liitrit bensiini kuus.']
# 773                                                                                                                                          ['Usbekistanis Andijoni vanglas suri novembris kaks vangi.', 'Vangid surid piinamise tagajärjel.', 'Mehi süüdistati islamiäärmusluses.', 'Selle ütlesid meeste sugulased ja inimõiguslased.']
#
#                             tags  tag initial_cat verb_head_same_sent  \
# 207                          NaN  NaN       a_n80                   y
# 221  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 272  |A|AE|AL|AS|AT|AET|ALT|AST|    A       a_n80                   y
# 773                          NaN    A       s_n80                   y
#
#     head_verbi_alluv
# 207                e
# 221                e
# 272                e
# 773                e

# %%
#errors

# %%
gpt_errors
# Out:
#      sentence_id   head_id  head_loc    verb verb_compound morph_case  \
# 247     12211695  19550360        16  uurima           NaN        abl
# 769      2089813   3334984        16  surema           NaN       adit
#
#          lemma        form  \
# 247        see     sellelt
# 769  puudumine  puudumisse
#
#                                                                                                                             sentence  \
# 247  Miks Romeo Kalda elu läks just nii , nagu ta läinud on , uuris Toimik sellelt ühelt Eestimaa ohtlikumalt kurjategijalt endalt .
# 769                   Elavad mõne kuu ja surevad siis madala temperatuuri , päikese või vähese söögiks kõlbliku heitvee puudumisse .
#
#                                                                                                                                                          simple_sentences_gpt4o  \
# 247        ['Toimik uuris Romeo Kaldalt midagi.', 'Romeo Kalda on üks Eestimaa ohtlikumaid kurjategijaid.', 'Toimik uuris, miks Romeo Kalda elu läks nii, nagu see läinud on.']
# 769  ['Nad elavad mõne kuu.', 'Nad surevad madala temperatuuri tõttu.', 'Nad surevad päikese puudumise tõttu.', 'Nad surevad vähese söögiks kõlbliku heitvee puudumise tõttu.']
#
#     tags tag initial_cat verb_head_same_sent head_verbi_alluv
# 247  NaN   A       a_n80                   ?                ?
# 769  NaN   S       s_n80                   ?                ?

# %% [markdown]
# # Kokkuvõte A ja S n80, mis on sõnastiku/gpt poolt saanud E/L/T (82 näidet)

# %%
same_sent = n80_elt[n80_elt["verb_head_same_sent"]=="y"]
not_same_sent = n80_elt[n80_elt["verb_head_same_sent"]=="n"]
not_same_but_error = not_same_sent[not_same_sent["head_verbi_alluv"]=="?"]
not_same_not_alluv = not_same_sent[not_same_sent["head_verbi_alluv"]=="n"]
not_same_orig_error =  not_same_sent[not_same_sent["head_verbi_alluv"]=="e"]
same_sent_alluv = same_sent[same_sent["head_verbi_alluv"]=="y"]
same_sent_replaced = same_sent[same_sent["head_verbi_alluv"]=="?"]
same_sent_kesksona = same_sent[same_sent["head_verbi_alluv"]=="k"]
same_sent_error = same_sent[same_sent["head_verbi_alluv"]=="e"]
#errors = n80_elt[n80_elt["verb_head_same_sent"]=="e"]
gpt_errors = n80_elt[n80_elt["verb_head_same_sent"]=="?"]

# %%
print("verb + peasõna on samas lihtlauses: ", len(same_sent))
print("verb+ps samas lihtlauses ja ps on verbi alluv: ", len(same_sent_alluv), "/", len(same_sent))
print("verb+ps samas lihtlauses aga peasõna on asendatud teise sõnaga (enamasti sisuliselt õige): ", len(same_sent_replaced), "/", len(same_sent))
print("verb+ps samas lihtlauses aga orig lauses kesksõna vorm: ", len(same_sent_kesksona), "/", len(same_sent))
print("verb+ps samas lihtlauses aga lauses probleem: ", len(same_sent_error), "/", len(same_sent))


print("\n")

print("verb + peasõna pole samas lihtlauses: ", len(not_same_sent))
print("verb+ps pole samas lihtlauses aga orig lauses on ps verbi alluv (gpt lausestamise viga):", len(not_same_but_error), "/", len(not_same_sent) )
print("verb+ps pole samas lihtlauses ja ps ei ole orig lauses verbi alluv:", len(not_same_not_alluv), "/", len(not_same_sent) )
print("verb+ps pole samas lihtlauses ja orig lauses midagi valesti:", len(not_same_orig_error), "/", len(not_same_sent) )

print("\n")

#print("peasõna süntaksi viga:", len(errors))
print("gpt lausestamisega muutus struktuur liiga palju:", len(gpt_errors))
# Out:
# verb + peasõna on samas lihtlauses:  76
# verb+ps samas lihtlauses ja ps on verbi alluv:  59 / 76
# verb+ps samas lihtlauses aga peasõna on asendatud teise sõnaga (enamasti sisuliselt õige):  1 / 76
# verb+ps samas lihtlauses aga orig lauses kesksõna vorm:  0 / 76
# verb+ps samas lihtlauses aga lauses probleem:  16 / 76
#
#
# verb + peasõna pole samas lihtlauses:  4
# verb+ps pole samas lihtlauses aga orig lauses on ps verbi alluv (gpt lausestamise viga): 2 / 4
# verb+ps pole samas lihtlauses ja ps ei ole orig lauses verbi alluv: 0 / 4
# verb+ps pole samas lihtlauses ja orig lauses midagi valesti: 2 / 4
#
#
# gpt lausestamisega muutus struktuur liiga palju: 1

# %%
not_same_sent
# Out:
#      sentence_id   head_id  head_loc       verb verb_compound morph_case  \
# 267      3329176   5354106         4  sätestama           NaN        all
# 330      5546970   8894196        10    laenama           NaN        abl
# 347      8824416  14171424         3     ütlema           ära        all
# 384     19671104  29228547         7  helistama           NaN        all
#
#        lemma        form  \
# 267    toode   toodetele
# 330    klubi     klubilt
# 347      töö     töödele
# 384  aastane  aastastele
#
#                                                                                                                                 sentence  \
# 267                                  Seadus sätestab teatud toodetele , nagu mootorsõidukid ja nende osad , tootja vastutuse põhimõtte .
# 330  Mart Poomi koduklubi Derby County laenas algavaks hooajaks Itaalia klubilt AC Milan kaitsemängija Daniele Daino , teatas Sportnet .
# 347                                                                      Ütlesin siiski töödele ja kohtumistele viidates viisakalt ära .
# 384                                                     helistage või messake kahele poisile 17 aastastele nr 058053904 ja te ei kahetse
#
#                                                                                                                                                                             simple_sentences_gpt4o  \
# 267                                                        ['Seadus sätestab tootja vastutuse põhimõtte.', 'See kehtib teatud toodetele.', 'Need tooted on näiteks mootorsõidukid ja nende osad.']
# 330  ['Mart Poomi koduklubi on Derby County.', 'Derby County laenas algavaks hooajaks kaitsemängija Daniele Daino.', 'Daniele Daino kuulub Itaalia klubile AC Milan.', 'Sportnet teatas sellest.']
# 347                                                                                                                                ['Ütlesin viisakalt ära.', 'Viitasin töödele ja kohtumistele.']
# 384                                                             ['Helistage kahele poisile.', 'Messake kahele poisile.', 'Poisid on 17-aastased.', 'Nende number on 058053904.', 'Te ei kahetse.']
#
#                                     tags tag initial_cat verb_head_same_sent  \
# 267                                  NaN   L       a_n80                   n
# 330                                  NaN   L       a_n80                   n
# 347                                  NaN   L       a_n80                   n
# 384  |T|AT|ET|LT|ST|AET|ALT|AST|ELT|LST|   A       a_n80                   n
#
#     head_verbi_alluv
# 267                ?
# 330                ?
# 347                e
# 384                e

# %%
not_same_but_error
# Out:
#      sentence_id  head_id  head_loc       verb verb_compound morph_case  \
# 267      3329176  5354106         4  sätestama           NaN        all
# 330      5546970  8894196        10    laenama           NaN        abl
#
#      lemma       form  \
# 267  toode  toodetele
# 330  klubi    klubilt
#
#                                                                                                                                 sentence  \
# 267                                  Seadus sätestab teatud toodetele , nagu mootorsõidukid ja nende osad , tootja vastutuse põhimõtte .
# 330  Mart Poomi koduklubi Derby County laenas algavaks hooajaks Itaalia klubilt AC Milan kaitsemängija Daniele Daino , teatas Sportnet .
#
#                                                                                                                                                                             simple_sentences_gpt4o  \
# 267                                                        ['Seadus sätestab tootja vastutuse põhimõtte.', 'See kehtib teatud toodetele.', 'Need tooted on näiteks mootorsõidukid ja nende osad.']
# 330  ['Mart Poomi koduklubi on Derby County.', 'Derby County laenas algavaks hooajaks kaitsemängija Daniele Daino.', 'Daniele Daino kuulub Itaalia klubile AC Milan.', 'Sportnet teatas sellest.']
#
#     tags tag initial_cat verb_head_same_sent head_verbi_alluv
# 267  NaN   L       a_n80                   n                ?
# 330  NaN   L       a_n80                   n                ?

# %%
not_same_not_alluv
# Out:
# Empty DataFrame
# Columns: [sentence_id, head_id, head_loc, verb, verb_compound, morph_case, lemma, form, sentence, simple_sentences_gpt4o, tags, tag, initial_cat, verb_head_same_sent, head_verbi_alluv]
# Index: []

# %%
not_same_orig_error
# Out:
#      sentence_id   head_id  head_loc       verb verb_compound morph_case  \
# 347      8824416  14171424         3     ütlema           ära        all
# 384     19671104  29228547         7  helistama           NaN        all
#
#        lemma        form  \
# 347      töö     töödele
# 384  aastane  aastastele
#
#                                                                              sentence  \
# 347                   Ütlesin siiski töödele ja kohtumistele viidates viisakalt ära .
# 384  helistage või messake kahele poisile 17 aastastele nr 058053904 ja te ei kahetse
#
#                                                                                                                  simple_sentences_gpt4o  \
# 347                                                                     ['Ütlesin viisakalt ära.', 'Viitasin töödele ja kohtumistele.']
# 384  ['Helistage kahele poisile.', 'Messake kahele poisile.', 'Poisid on 17-aastased.', 'Nende number on 058053904.', 'Te ei kahetse.']
#
#                                     tags tag initial_cat verb_head_same_sent  \
# 347                                  NaN   L       a_n80                   n
# 384  |T|AT|ET|LT|ST|AET|ALT|AST|ELT|LST|   A       a_n80                   n
#
#     head_verbi_alluv
# 347                e
# 384                e

# %%
same_sent.sample(5)
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 328      1075921   1710391        11  võimaldama           NaN        all
# 321      1959553   3124405         4       andma           üle        all
# 210     12407194  19864326         7  tunnistama           NaN        all
# 255     18001689  27393337        15     rääkima           ära        all
# 695      6097357   9787582         7      surema           NaN       adit
#
#            lemma            form  \
# 328        konto       kontodele
# 321        klubi         klubile
# 210  kriisiõppus  kriisiõppusele
# 255         põli       põlvedele
# 695         võrk           võrku
#
#                                                                                                                                                                  sentence  \
# 328    Loodavad lahendused võimaldavad Swedbanki grupi klientidel mobiilside kaudu juurdepääsu oma kontodele ja teha ülekandeid Ericssoni EPOC-tüüpi mobiiltelefonidega .
# 321                                                                                                               Karika enda andis klubile üle Pärkma tütar Helve Tähe .
# 210                                                                                             Teatrijuhtimise praktika tunnistab ta just tänu kriisiõppusele tugevaks .
# 255  Nii mõnigi tollaste sündmuste asjaosaline võiks endalt küsida , kas ta on ikka järeltulevatele põlvedele ausalt ära rääkinud , mis Võrus 21. oktoobril 1987 juhtus .
# 695                                                                        Tean , et kalurid , kelle võrku viigerhüljes on surnud , ei julge sellest tavaliselt teatada .
#
#                                                                                                                                                                                      simple_sentences_gpt4o  \
# 328  ['Loodavad lahendused võimaldavad Swedbanki grupi klientidel mobiilside kaudu juurdepääsu oma kontodele.', 'Loodavad lahendused võimaldavad teha ülekandeid Ericssoni EPOC-tüüpi mobiiltelefonidega.']
# 321                                                                                                                              ['Pärkma tütar Helve Tähe andis karika üle.', 'Karikas anti üle klubile.']
# 210                                                                                           ['Teatrijuhtimise praktika on tugev.', 'Ta tunnistab teatrijuhtimise praktika tugevaks tänu kriisiõppusele.']
# 255           ['Mõned tollaste sündmuste asjaosalised võiksid endalt midagi küsida.', 'Nad võiksid küsida, kas nad on järeltulevatele põlvedele ausalt ära rääkinud, mis Võrus 21. oktoobril 1987 juhtus.']
# 695                                                                                                                   ['Kalurid, kelle võrku viigerhüljes on surnud, ei julge sellest tavaliselt teatada.']
#
#     tags tag initial_cat verb_head_same_sent head_verbi_alluv
# 328  NaN   L       a_n80                   y                y
# 321  NaN   L       a_n80                   y                y
# 210  NaN   E       a_n80                   y                e
# 255  NaN   L       a_n80                   y                y
# 695  NaN   L       s_n80                   y                y

# %%
same_sent_alluv.sample(10)
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 204      6485006  10429095        22     kehtima           NaN        all
# 343      2460593   3944552        29      maksma         kinni        all
# 202      4033611   6491937         7      kandma          ette        all
# 711      7110414  11435633         5      surema           NaN       adit
# 248      9975055  16000359         9      laulma           NaN        all
# 263      7057846  11341038         9     karjuma           NaN        all
# 310     17514698  26853056         5     kehtima           NaN        all
# 313      8475395  13584896        16      tasuma           NaN        all
# 268      5435058   8714384        41  võimaldama           NaN        all
# 289      4910536   7884394        13     laenama           NaN        abl
#
#                  lemma                    form  \
# 204              Iraan                Iraanile
# 343             soojus               Soojusele
# 202               ECRI                 ECRI-le
# 711            pimedus               pimedusse
# 248               vokk                  vokile
# 263                uks                  uksele
# 310     krediidiasutus      krediidiasutustele
# 313              Hiina                 Hiinale
# 268  internetilehekülg  internetilehekülgedele
# 289             Rožoki                Rožokilt
#
#                                                                                                                                                                                                                                                                                                                  sentence  \
# 204                                                                                                                                                               Ma tean , et täieliku kütusetsükli hankimine tähendab , et riik on mõne kuu kaugusel tuumarelvadest , ja see kehtib nii Iraanile kui kõigile teistele .
# 343  Laanjärve sõnul ajendas linnaosa juhtumit uurima ajakirjanduses esinenud väide , nagu oleks BREM-i oktoobris esitatud nõue Tallinnale tekkinud seoses erastamiseelse kahtlase tehinguga , kus Pae Kinnisvarahooldus maksis Tallinna Soojusele 26,3 miljoni krooni ulatuses kinni Lasnamäe linnaosa valitsuse võlgu .
# 202                                                                                                                                                                                                                                        Ei tea , kes selliseid andmeid ECRI-le ette kannab - ega ometi mustlased ise !
# 711                                                                                                                                                                                                                                  Kui valgus ei sure pimedusse , siis ei saabu kunagi uus päev , uus kuu , uus aasta ?
# 248                                                                                                                                                                                                              Öösiti ning varahommikuti käsitööd tehes on ta laulnud vokile , kerilauale ja kõigile muudele asjadele .
# 263                                                                                                                                                                                                                                                                        " Mitte iial ! " karjus ta kirsipuust uksele .
# 310                                                                                                                                                                                                                        Litsentseerimise tingimused kehtivad kõikidele krediidiasutustele kogu tegutsemisaja jooksul .
# 313                                                                                                                                    “ Aga ma ei oleks sellele kindlasti alla kirjutanud , sest peab tajuma , miks Hiinale ei tasu Tiibeti peale soola raputada ja Venemaale pole mõtet Tshetsheeniale soola raputada .
# 268                Esmaspäeval teatas Saksamaa Juutide Kesknõukogu ( Central Council for Jews ) , et hakkab järjest kohtusse kaebama interneti teenusepakkujaid ( ehk siis Eestis näiteks Eesti Telefon , Tele 2 jne ) , kui need võimaldavad kasutajatel ligipääsu natside ja parem-äärmuslaste internetilehekülgedele .
# 289                                                                                   Kannatanu Ene Tšernõštšuk tunnistas kohtule , et on oma ammuselt healt tuttavalt Rožokilt korduvalt oma firma jaoks suuri summasid laenanud ning on talle senini umbes 8000 USA dollarit ehk ligikaudu 133.000 Eesti krooni võlgu .
#
#                                                                                                                                                                                                                                                                                                                              simple_sentences_gpt4o  \
# 204                                                                                                                                                                                         ['Ma tean, et täieliku kütusetsükli hankimine tähendab, et riik on mõne kuu kaugusel tuumarelvadest.', 'See kehtib nii Iraanile kui kõigile teistele.']
# 343       ['Laanjärve sõnul ajendas linnaosa juhtumit uurima ajakirjanduses esinenud väide.', 'Väite kohaselt oli BREM-i oktoobris esitatud nõue Tallinnale seotud kahtlase tehinguga.', 'Tehing toimus enne erastamist.', 'Pae Kinnisvarahooldus maksis Tallinna Soojusele 26,3 miljoni krooni ulatuses kinni Lasnamäe linnaosa valitsuse võlgu.']
# 202                                                                                                                                                                                                                                                              ['Ei tea, kes selliseid andmeid ECRI-le ette kannab.', 'Ega ometi mustlased ise!']
# 711                                                                                                                                                ['Kui valgus ei sure pimedusse, siis ei saabu kunagi uus päev.', 'Kui valgus ei sure pimedusse, siis ei saabu kunagi uus kuu.', 'Kui valgus ei sure pimedusse, siis ei saabu kunagi uus aasta.']
# 248                                                                                                                                                                                                  ['Ta teeb käsitööd öösiti ja varahommikuti.', 'Ta on laulnud vokile.', 'Ta on laulnud kerilauale.', 'Ta on laulnud kõigile muudele asjadele.']
# 263                                                                                                                                                                                                                                                               ['Ta karjus midagi.', 'Ta karjus kirsipuust uksele.', 'Ta karjus: "Mitte iial!"']
# 310                                                                                                                                                                                                                       ['Litsentseerimise tingimused kehtivad kõikidele krediidiasutustele.', 'Tingimused kehtivad kogu tegutsemisaja jooksul.']
# 313                                                                                                                                                    ['Ma ei oleks sellele kindlasti alla kirjutanud.', 'Peab tajuma, miks Hiinale ei tasu Tiibeti peale soola raputada.', 'Peab tajuma, miks Venemaale pole mõtet Tšetšeeniale soola raputada.']
# 268  ['Saksamaa Juutide Kesknõukogu teatas midagi.', 'See juhtus esmaspäeval.', 'Saksamaa Juutide Kesknõukogu hakkab järjest kohtusse kaebama interneti teenusepakkujaid.', 'Näiteks Eestis on teenusepakkujad Eesti Telefon ja Tele 2.', 'Teenusepakkujad võimaldavad kasutajatel ligipääsu natside ja parem-äärmuslaste internetilehekülgedele.']
# 289                                                                ['Kannatanu Ene Tšernõštšuk tunnistas kohtule, et ta on oma ammuselt healt tuttavalt Rožokilt korduvalt suuri summasid laenanud.', 'Ene Tšernõštšuk tunnistas, et ta on Rožokile senini umbes 8000 USA dollarit võlgu.', '8000 USA dollarit on ligikaudu 133 000 Eesti krooni.']
#
#                             tags tag initial_cat verb_head_same_sent  \
# 204  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       a_n80                   y
# 343  |A|AE|AL|AS|AT|AET|ALT|AST|   L       a_n80                   y
# 202                          NaN   L       a_n80                   y
# 711                          NaN   L       s_n80                   y
# 248                          NaN   L       a_n80                   y
# 263                          NaN   L       a_n80                   y
# 310  |A|AE|AL|AS|AT|AET|ALT|AST|   L       a_n80                   y
# 313  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       a_n80                   y
# 268                          NaN   L       a_n80                   y
# 289  |L|AL|EL|LS|LT|ALT|ELT|LST|   A       a_n80                   y
#
#     head_verbi_alluv
# 204                y
# 343                y
# 202                y
# 711                y
# 248                y
# 263                y
# 310                y
# 313                y
# 268                y
# 289                y

# %%
same_sent_replaced
# Out:
#      sentence_id   head_id  head_loc    verb verb_compound morph_case  lemma  \
# 391     14263201  22641300         8  laulma           NaN        all  elamu
#
#         form  \
# 391  elamule
#
#                                                                                                                                                   sentence  \
# 391  Üle viigipükste ääre valguva kõhukese võbisedes laulab elamule ülistuslaulu ja nendib ohates , et noortel on tänapäeval tõesti raske elupinda leida .
#
#                                                                                                                                              simple_sentences_gpt4o  \
# 391  ['Üle viigipükste ääre valguv kõhuke võbiseb.', 'Kõhuke laulab elamule ülistuslaulu.', 'Kõhuke nendib ohates, et noortel on tänapäeval raske elupinda leida.']
#
#                             tags tag initial_cat verb_head_same_sent  \
# 391  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       a_n80                   y
#
#     head_verbi_alluv
# 391                ?

# %%
same_sent_kesksona
# Out:
# Empty DataFrame
# Columns: [sentence_id, head_id, head_loc, verb, verb_compound, morph_case, lemma, form, sentence, simple_sentences_gpt4o, tags, tag, initial_cat, verb_head_same_sent, head_verbi_alluv]
# Index: []

# %%
same_sent_error
# Out:
#      sentence_id   head_id  head_loc        verb verb_compound morph_case  \
# 210     12407194  19864326         7  tunnistama           NaN        all
# 274      9361911  15036299         1    pakutama           NaN        all
# 291     10000631  16042033         9   meenutama           NaN        all
# 302     18553232  28083547         1   soovitama           NaN        all
# 305      9012778  14490858        25      tasuma           NaN        all
# 612      5654815   9068765        12    nakatuma           NaN       adit
# 630       867688   1382145         2      surema           NaN       adit
# 635      6364090  10226621        15  haigestuma           NaN       adit
# 658      1963565   3131233        13      surema           NaN       adit
# 659     17061507  26224260         8      surema           NaN       adit
# 728      5912917   9491645         5  haigestuma           NaN       adit
# 735     10003683  16047299        13      surema           NaN       adit
# 751      4496828   7230399        17      surema           NaN       adit
# 758      6632469  10672191        16  haigestuma           NaN        ill
# 775      5764928   9248055        12      surema           NaN       adit
# 783       933744   1487131        11      surema           NaN       adit
#
#               lemma               form  \
# 210     kriisiõppus     kriisiõppusele
# 274    investeering  Investeeringutele
# 291             tee            teedele
# 302       kõvaketas        Kõvakettale
# 305  majandussuhted   majandussuhetele
# 612        veresoon         veresoonde
# 630         ajakiri           ajakirja
# 635            kodu               koju
# 658            veen              veeni
# 659      Kuressaare        Kuressaarde
# 728              EM               EM-i
# 735     pensioniiga       pensioniikka
# 751     sõjaväebaas       sõjaväebaasi
# 758    Philadelphia    Philadelphiasse
# 775       heinakuhi         heinakuhja
# 783         pealinn           pealinna
#
#                                                                                                                                                                                                         sentence  \
# 210                                                                                                                                    Teatrijuhtimise praktika tunnistab ta just tänu kriisiõppusele tugevaks .
# 274                                                                                             Investeeringutele pakutavad maksuvabadused on pannud riigid eriti teravalt konkureerima kapitalimaksude rindel .
# 291                                                                                        Auklikule Pärnu maanteele jõudes meenutasid soomlased reise Venemaa teedele , mis klopib peaaegu hambad suust välja .
# 302                                                                                                                                                   Kõvakettale , kus Linux ise asub , ei soovita seda panna .
# 305  Äsja Mordvast naasnud Eesti Moskva-suursaadik Tiit Matsulevitsh arvab , et Eesti ei peaks suhtluses soome-ugri sugulasrahvastega piirduma vaid kultuurikoostööga , vaid mõelda tasuks ka majandussuhetele .
# 612                                                                                                                  1 206 HIV juhtumist 71% ehk 836 inimest nakatusid HIVsse uimastite süstimisega veresoonde .
# 630                                                                                                                                                                         Suri ajakirja Novõi Mir peatoimetaja
# 635                                                                                                   Tegemist oli kaks aastat Hiinas Guandongi provintsis töötanud 33aastase mehega , kes haigestus teel koju .
# 658                                                   Kaheksa ühe Bangladeshi haigla patsienti surid pärast vananenuks osutunud füsioloogilise lahuse manustamist veeni , 15 inimesel aga tekkis kõrge palavik .
# 659                                                                                                 Pakk oli kaks aastat tagasi saadetud Tallinnast Kuressaarde surnud Lembitu õele , et too venna maha mataks .
# 728                                                                                                            Vend Aleksei haigestus vahetult EM-i eel ja oli sunnitud treeningutes tegema kümnepäevase pausi .
# 735                                                                            Lisaks veel kaks näitajat , mittetüüpilised rahuaja riigile - mehed surid keskmiselt pensioniikka jõudmata ja ülimadal sündimus .
# 751                                                                                                           Ta sai pihta mürsuga , mis teda väga raskelt haavas , ning arvatavasti suri ta teel sõjaväebaasi .
# 758                                                                       Eesti Merelaevanduse madrus , saanud küll eelnevalt malaaria kemoprofülaktikat , haigestus 12. juunil teel Aafrikast Philadelphiasse .
# 775                                                                                                                             " Buridanid " said oma nime eesli järgi , kes kahe heinakuhja vahel nälga suri .
# 783                                                                                          84-aastane Bandaranaike osales eile oma kodumaakonnas parlamendivalimistel ja suri tagasiteel pealinna Colombosse .
#
#                                                                                                                                                                                                                                                                      simple_sentences_gpt4o  \
# 210                                                                                                                                                                           ['Teatrijuhtimise praktika on tugev.', 'Ta tunnistab teatrijuhtimise praktika tugevaks tänu kriisiõppusele.']
# 274                                                                                                                     ['Investeeringutele pakutavad maksuvabadused on pannud riigid konkureerima kapitalimaksude rindel.', 'Riigid konkureerivad kapitalimaksude rindel eriti teravalt.']
# 291                                                                                                                                    ['Soomlased jõudsid auklikule Pärnu maanteele.', 'Soomlased meenutasid reise Venemaa teedele.', 'Venemaa teed klopivad peaaegu hambad suust välja.']
# 302                                                                                                                                                                                                      ['Linux asub kõvakettal.', 'Seda ei soovitata panna kõvakettale, kus Linux asub.']
# 305  ['Tiit Matsulevitsh on Eesti Moskva-suursaadik.', 'Tiit Matsulevitsh naasis äsja Mordvast.', 'Tiit Matsulevitsh arvab, et Eesti ei peaks suhtluses soome-ugri sugulasrahvastega piirduma ainult kultuurikoostööga.', 'Tiit Matsulevitsh arvab, et tasuks mõelda ka majandussuhetele.']
# 612                                                                                                                                                                                          ['1 206 HIV juhtumist 71% ehk 836 inimest nakatusid HIVsse uimastite süstimisega veresoonde.']
# 630                                                                                                                                                                                                                                               ['Suri ajakirja Novõi Mir peatoimetaja.']
# 635                                                                                                                                                                ['Tegemist oli 33-aastase mehega.', 'Mees töötas kaks aastat Hiinas Guandongi provintsis.', 'Mees haigestus teel koju.']
# 658                                                                                                        ['Kaheksa ühe Bangladeshi haigla patsienti surid.', 'Patsiendid surid pärast vananenuks osutunud füsioloogilise lahuse manustamist veeni.', '15 inimesel tekkis kõrge palavik.']
# 659                                                                                                                                                          ['Pakk saadeti kaks aastat tagasi Tallinnast Kuressaarde.', 'Pakk saadeti surnud Lembitu õele.', 'Õde pidi venna maha matma.']
# 728                                                                                                                                                                     ['Vend Aleksei haigestus vahetult enne EM-i.', 'Vend Aleksei oli sunnitud treeningutes tegema kümnepäevase pausi.']
# 735                                                                                                                                                                                                             ['Mehed surid keskmiselt pensioniikka jõudmata.', 'Sündimus oli ülimadal.']
# 751                                                                                                                                                                                  ['Ta sai pihta mürsuga.', 'Mürsk haavas teda väga raskelt.', 'Ta arvatavasti suri teel sõjaväebaasi.']
# 758                                                                                                                                                ['Eesti Merelaevanduse madrus sai eelnevalt malaaria kemoprofülaktikat.', 'Madrus haigestus 12. juunil teel Aafrikast Philadelphiasse.']
# 775                                                                                                                                                                                                   ['«Buridanid» said oma nime eesli järgi.', 'Eesel suri kahe heinakuhja vahel nälga.']
# 783                                                                                                                                                              ['84-aastane Bandaranaike osales eile oma kodumaakonnas parlamendivalimistel.', 'Ta suri tagasiteel pealinna Colombosse.']
#
#                             tags tag initial_cat verb_head_same_sent  \
# 210                          NaN   E       a_n80                   y
# 274                          NaN   L       a_n80                   y
# 291                          NaN   L       a_n80                   y
# 302                          NaN   L       a_n80                   y
# 305                          NaN   L       a_n80                   y
# 612                          NaN   L       s_n80                   y
# 630                          NaN   L       s_n80                   y
# 635  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       s_n80                   y
# 658                          NaN   L       s_n80                   y
# 659  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       s_n80                   y
# 728                     |EL|ELT|   E       s_n80                   y
# 735                          NaN   T       s_n80                   y
# 751  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       s_n80                   y
# 758  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       s_n80                   y
# 775                          NaN   L       s_n80                   y
# 783  |L|AL|EL|LS|LT|ALT|ELT|LST|   L       s_n80                   y
#
#     head_verbi_alluv
# 210                e
# 274                e
# 291                e
# 302                e
# 305                e
# 612                e
# 630                e
# 635                e
# 658                e
# 659                e
# 728                e
# 735                e
# 751                e
# 758                e
# 775                e
# 783                e

# %%
#errors

# %%
gpt_errors
# Out:
#      sentence_id  head_id  head_loc    verb verb_compound morph_case  lemma  \
# 784      6215791  9983047         5  surema           NaN       adit  sketš
#
#        form  \
# 784  sketši
#
#                                                                                                                                                                                                   sentence  \
# 784  Kui parafraseerida Monty Pythoni sketši surnud papagoist , siis tuleb Tony Blair Tallinna sõnumiga " It is not dead , it's merely resting " - s.t eesistumisel pole häda midagi , tuleb vaid oodata .
#
#                                                                                                                                                    simple_sentences_gpt4o  \
# 784  ['Tony Blair tuleb Tallinna sõnumiga.', 'Sõnum on "It is not dead, it\'s merely resting".', 'See tähendab, et eesistumisel pole häda midagi.', 'Tuleb vaid oodata.']
#
#     tags tag initial_cat verb_head_same_sent head_verbi_alluv
# 784  NaN   L       s_n80                   ?                ?
