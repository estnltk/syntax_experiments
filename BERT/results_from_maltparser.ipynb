# %% [markdown]
# ## Training maltparser
#
# Data: EDT conllx treebank (without any augmentation)

# %% [markdown]
# |     | Train |       |       | Test  |       |       |
# |-----|-------|-------|-------|-------|-------|-------|
# | fold    | LA    | UAS   | LAS   | LA    | UAS   | LAS   |
# | 1   | 97.41 | 96.11 | 95.20 | 90.89 | 87.47 | 84.60 |
# | 2   | 97.43 | 96.09 | 95.20 | 91.75 | 88.30 | 85.72 |
# | 3   | 97.35 | 96.02 | 95.10 | 91.60 | 88.94 | 86.11 |
# | 4   | 97.4  | 96.06 | 95.16 | 91.24 | 88.28 | 85.49 |
# | 5   | 97.39 | 96.07 | 95.17 | 90.92 | 87.48 | 84.64 |
# | 6   | 97.38 | 96.08 | 95.17 | 90.99 | 87.78 | 84.89 |
# | 7   | 97.40 | 96.12 | 95.19 | 91.14 | 88.05 | 85.29 |
# | 8   | 97.41 | 96.00 | 95.12 | 90.88 | 87.44 | 84.77 |
# | 9   | 97.36 | 96.01 | 95.10 | 91.45 | 88.01 | 85.39 |
# | 10  | 97.37 | 96.06 | 95.13 | 91.39 | 88.12 | 85.47 |
# | AVG | 97.39 | 96.06 | 95.15 | 91.23 | 87.99 | 85.24 |

# %% [markdown]
# Data: EDT conllx treebank + augmented train data (filtered by POS and morph)
#
# |     | Train  |        |        | Test   |        |        |
# |-----|--------|--------|--------|--------|--------|--------|
# |     | LA     | UAS    | LAS    | LA     | UAS    | LAS    |
# | 1   | 99.51  | 99.28  | 99.09  | 90.1   | 86.54  | 83.4   |
# | 2   | 99.51  | 99.29  | 99.1   | 90.77  | 87.95  | 84.14  |
# | 3   | 99.5   | 99.26  | 99.06  | 90.94  | 87.82  | 84.9   |
# | 4   | 99.51  | 99.25  | 99.06  | 90.52  | 87.17  | 84.17  |
# | 5   | 99.51  | 99.26  | 99.07  | 90.19  | 86.25  | 83.24  |
# | 6   | 99.53  | 99.29  | 99.11  | 90.26  | 86.87  | 83.72  |
# | 7   | 99.5   | 99.25  | 99.06  | 90.39  | 86.93  | 83.99  |
# | 8   | 99.51  | 99.26  | 99.07  | 90.11  | 86.15  | 83.31  |
# | 9   | 99.5   | 99.26  | 99.07  | 90.56  | 86.85  | 84.07  |
# | 10  | 99.49  | 99.25  | 99.06  | 90.67  | 86.92  | 84.15  |
# | AVG | 99.507 | 99.265 | 99.075 | 90.451 | 86.945 | 83.909 |

# %% [markdown]
# Data: original data (trained on augmented dataset)
#
# |     | Train  |        |        | Test   |        |        |
# |-----|--------|--------|--------|--------|--------|--------|
# |     | LA     | UAS    | LAS    | LA     | UAS    | LAS    |
# | 1   | 98.72  | 98.72  | 97.57  | 90.1   | 86.54  | 83.4   |
# | 2   | 98.7   | 98.06  | 97.6   | 90.77  | 87.95  | 84.14  |
# | 3   | 98.7   | 98     | 97.55  | 90.94  | 87.82  | 84.9   |
# | 4   | 98.69  | 97.99  | 97.53  | 90.52  | 87.17  | 84.17  |
# | 5   | 98.72  | 98.06  | 97.61  | 90.19  | 86.25  | 83.24  |
# | 6   | 98.74  | 98.06  | 97.62  | 90.26  | 86.87  | 83.72  |
# | 7   | 98.7   | 98.03  | 97.57  | 90.39  | 86.93  | 83.99  |
# | 8   | 98.74  | 98.09  | 97.64  | 90.11  | 86.15  | 83.31  |
# | 9   | 98.68  | 97.97  | 97.52  | 90.56  | 86.85  | 84.07  |
# | 10  | 98.66  | 97.97  | 97.5   | 90.67  | 86.92  | 84.15  |
# | AVG | 98.705 | 98.095 | 97.571 | 90.451 | 86.945 | 83.909 |
