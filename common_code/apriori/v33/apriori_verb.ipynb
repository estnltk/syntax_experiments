# %%
#!pip install sqlalchemy pandas mlxtend seaborn
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Verbimallid apriori
# v30 täiendatud variant. Põhiline erinevus: selles versioonis on andmebaasi fail juba eelfiltreeritud deprel'ide osas ning
#
# * v33 - terviklik (puhastatud) verbifraas väljal transactions_head.phrase
# * v32 - [jäi vahele]
# * v31
#   * verbi relatsioonid ei sisalda enam ebaolulisi deprel-e
#   * lisaks verbi otsestele alluvatele sisalduvad andmebaasis ka verbile alluvate obl-de alluvad case-tipud.
# * v30 algne

# %% [markdown]
# ## Ülesande esialgne kirjeldus Svenilt
# 1. Transaktsioonide sisu filtreerimine
#     - Kadrit ei huvita vebile alluvad kirjavahemärgid
#     - Kadrit ei huvita verbile alluv kõrvallause.
#       (ma sõin putru ja vaatasin televiisorit)
#       Vastav alampuu on spetsiifilise deprel nimega (sinu näites cc ja veel ka conj)
#       Kontrolli seda ise vaadates erinevaid liitlauseid läbi. Kadri saab sind selles osas aidata
#    - Vaata et transaktsiooni ei jääks ühendverbi liite osa (kirjutas maha --> maha), sest see on müra
#
# 2. Transaktsiooni item-ite moodustamine
#     - Kadri meelest pole ainuse ja mitmuse eristamine oluline välja arvatud subject/objekt tippudes
#     - Item peaks olema deprel + form.
#       Sul on mingit tipud deprel + form1, form2 kuidas see tekkida sai
#       Näiteks {'deprel': 'nsubj', 'feats': 'com,nom,sg'} -- kas see on mitmene morf analüüs? Kui jah, kas sa saad siis com | nom kasutada
# - sõnavormide lisamine item-i sisse.
# Võiks olla mingi lävend, et kui sõnavorm on antud deprel-i all sagedamini kui 20% siis jääb see ka alles
# magas und --> und on obj ja peaaegfu ainus võimalik obj verbiga magama
#
#
# 3. Itemset mining. Sellele on vaja peale visata almost-closed set filter
#
# Sa hakkad tulemusi vaatama kõige pikematest alamhulkadest
#
#
# Olgu sul pikk alamhulk X sagedusega t_X ja olgu Y selle ühe itemiga vähem hulk st Y + {a} = X
# Siis tuleb hulk Y kustutada kui selle sagedus t_y >= t_x - delta, kus delta on mingi lävend
# Standard juhul on delta=0, aga meie rakenduses võiks delta olla 2-5% kui sa mõõdad sagedust protsentides
#
#
# Kui sa nii, kontrollid elementide arvu järgi tagurpidiselt järjestatud hulki, saad kompaktse esituse, mida meil vaja on
#
#
# 4. Tulemuse esitus
#
#
# Graafiline heatmap, Pane allesjäänud hulgad 0/1 kodeeringus heatmapile
#
#
# Järjestus peaks olema SUB, OBJ, OBL1, ...OBLx, muud
# Kadri annab täpse järjestuse

# %% [markdown]
# ## Märkused
#
# * compound:prt-d alluvat ei ignoreerita kui compound=None
# * andmestikust on müra eemaldatud Kadri poolt etteantud nimekirja alusel
# * <font color="red">andmebaas sisaldab ka selliseid transaction_head kirjeid, millel pole ühtegi relevantset alluvat</font>

# %% [markdown]
# # Algseadistamine

# %%
DB_FILE = "/databases/v33_data.db"

# %%
import pandas as pd
import sys
sys.path.append('../../')
from paths import PATH_COMMON_CODE, PATH_ROOT
sys.path.append(PATH_COMMON_CODE)
from apriori import V33

pd.set_option('display.max_colwidth', 0)

v33 = V33(
    PATH_ROOT + DB_FILE,
    form_treshold_percent = 20,
    form_treshold_count = 5,
    apriori_min_support=0.05,
    apriori_treshold_delta = 0.03,
    apriori_treshold_percent=50,
    datarows_treshold=100000
    )

# %% [markdown]
# ## vaidlema

# %%
# %%time
result = v33.make_all(verb='vaidlema', verb_compound='', examples=True)
# Out:
# ************************************************ vaidlema   ************************************************
# Ridu analüüsimiseks: 3598
# apriori min_support: 0.05
# delta: 0.03
# percent: 50
#      support                                               itemlists  \
# 5   0.669817  [(NSUBJ, nom, , )]
# 1   0.394942  [(ADVMOD, , , )]
# 13  0.267093  [(NSUBJ, nom, , ), (ADVMOD, , , )]
# 9   0.234297  [(OBL, gen, ,  üle)]
# 19  0.180100  [(NSUBJ, nom, , ), (OBL, gen, ,  üle)]
# 11  0.157310  [(OBL, kom, , )]
# 3   0.141745  [(AUX, , ei, )]
# 2   0.123680  [(AUX, , , )]
# 14  0.106726  [(OBL, gen, ,  üle), (ADVMOD, , , )]
# 17  0.101167  [(NSUBJ, nom, , ), (AUX, , ei, )]
# 20  0.092273  [(NSUBJ, nom, , ), (OBL, kom, , )]
# 21  0.086437  [(NSUBJ, nom, , ), (OBL, gen, ,  üle), (ADVMOD, , , )]
# 7   0.070595  [(OBL, ad, , )]
# 0   0.068093  [(ADVCL, , , )]
# 16  0.060589  [(NSUBJ, nom, , ), (AUX, , , )]
# 10  0.056976  [(OBL, in, , )]
# 6   0.056420  [(OBJ, gen, , )]
# 12  0.053363  [(ADVMOD, , , ), (AUX, , , )]
# 15  0.053085  [(OBL, kom, , ), (ADVMOD, , , )]
# 8   0.051695  [(OBL, gen, ,  vastu)]
# 18  0.051695  [(NSUBJ, nom, , ), (OBL, ad, , )]
# 4   0.051417  [(CCOMP, , , )]
#
#                                    example1  \
# 5   nemad
# 1   siin
# 13  me tõsiselt
# 9   mille  üle
# 19  meri värsside  üle
# 11  piirivalvuriga
# 3   ei
# 2   ärge
# 14  mille  üle tuliselt
# 17  ma ei
# 20  ülikool sotsiaalministeeriumiga
# 21  kalandusametnikud püüginormide  üle aga
# 7   teemal
# 0   võeti
# 16  teoreetikud on
# 10  lennukis
# 6   usaldusväärsuse
# 12  jah ärge
# 15  kellega ükskord
# 8   sätte  vastu
# 18  keskkonnainspektor esmaspäeval
# 4   olid
#
#                                example2                       example3   drop  \
# 5   nad                                  koossesid                      False
# 1   kõigepealt                           siis                           False
# 13  nad parajasti                        inimesed las                   False
# 9   aja  üle                             selle  üle                     False
# 19  ärimehed saatuse  üle                riigikogu selle  üle           False
# 11  alessandroga                         emaga                          False
# 3   ei                                   ei                             False
# 2   on                                   oleme                          False
# 14  mille  üle vaid                      ristsõnade  üle peaasjalikult  True
# 17  nad ei                               me ei                          False
# 20  sina kuningaga                       ma hendrikuga                  False
# 21  liidrid valitsusprogrammi  üle eile  me küsimuste  üle alles        False
# 7   sõnul                                ajal                           True
# 0   meenutada                            meeldib                        False
# 16  pärijad on                           lõbustusasutused pole          False
# 10  eestis                               arbitraažikohtus               False
# 6   poliitika                            maaelu                         False
# 12  üldse ärgu                           siis olen                      False
# 15  nendega pidevalt                     naisega pidevalt               False
# 8   ühinemise  vastu                     eelnõu  vastu                  False
# 18  prints teatel                        vaimueliit kümnendil           False
# 4   kuulutada                            mõjutab                        False
#
#                                                                      drop_reason  \
# 5
# 1
# 13
# 9
# 19
# 11
# 3
# 2
# 14  (row 21) delta: abs(0.0864 - 0.1067) < 0.03 %: (0.1067-0.0864)/0.0864*100<50
# 17
# 20
# 21
# 7   (row 18) delta: abs(0.0517 - 0.0706) < 0.03 %: (0.0706-0.0517)/0.0517*100<50
# 0
# 16
# 10
# 6
# 12
# 15
# 8
# 18
# 4
#
#     length
# 5   1
# 1   1
# 13  2
# 9   1
# 19  2
# 11  1
# 3   1
# 2   1
# 14  2
# 17  2
# 20  2
# 21  3
# 7   1
# 0   1
# 16  2
# 10  1
# 6   1
# 12  2
# 15  2
# 8   1
# 18  2
# 4   1
# CPU times: user 6.29 s, sys: 3.45 s, total: 9.74 s
# Wall time: 19.3 s

# %% [markdown]
# ## vaidlema filtreeritud transaktsioonidega

# %%
# kõik vaidlema transaktsioonid apriori algoritmile sobival kujul
all_transactions = v33.get_transactions(verb="vaidlema", verb_compound="")
# v33._raw_transactions sisemuutujas on salvestatud kõik need transaktsioonid kohendamata kujul
# küll on seal feature, et 'form' asemel on 'frequent_form'
display(all_transactions[list(all_transactions.keys())[0]])
# kui on vaja lisaandmeid, neid saab sama id järgi kätte siit
display(v33._raw_transactions[list(all_transactions.keys())[0]])
# Out:
# [{'deprel': 'ADVMOD', 'case': '', 'frequent_form': '', 'obl_case': ''},
#  {'deprel': 'NSUBJ', 'case': 'nom', 'frequent_form': '', 'obl_case': ''},
#  {'deprel': 'ADVMOD', 'case': '', 'frequent_form': '', 'obl_case': ''}]
# [{'deprel': 'ADVMOD',
#   'case': '',
#   'feats': '',
#   'lemma': 'loomulikult',
#   'frequent_form': 'loomulikult',
#   'obl_case': '',
#   'loc': 1},
#  {'deprel': 'NSUBJ',
#   'case': 'nom',
#   'feats': 'nom,pl',
#   'lemma': 'mina',
#   'frequent_form': 'me',
#   'obl_case': '',
#   'loc': 2},
#  {'deprel': 'ADVMOD',
#   'case': '',
#   'feats': '',
#   'lemma': 'ikka',
#   'frequent_form': 'ikka',
#   'obl_case': '',
#   'loc': 3}]

# %%
# transaktsioonid, mida antakse apriori sisendiks
# neid võib olla kas vähem, või nad võivad olla muudetud sisuga

altered_transactions = {}

# eemaldane nt välja kõik NSUBJ ja kui muid ridu ei jää, siis ei saada seda transaktsiooni analüüsimisele

for head_id, tr_rows in all_transactions.items():
    all_deprels = list(set([r['deprel'] for r in tr_rows]))
    # kui ainus deprel ongi 'NSUBJ'
    if all_deprels == ['NSUBJ']:
        continue
    # võtame kõik deprelid peale 'NSUBJ'
    altered_transactions[head_id] = [r for r in tr_rows if r['deprel'] not in ['NSUBJ']]
    
display(altered_transactions[list(altered_transactions.keys())[0]])
# Out:
# [{'deprel': 'ADVMOD', 'case': '', 'frequent_form': '', 'obl_case': ''},
#  {'deprel': 'ADVMOD', 'case': '', 'frequent_form': '', 'obl_case': ''}]

# %%
# filtreerimata apriori tulemus
df_apriori_unfiltered = v33.apriori(altered_transactions)
df_apriori_unfiltered
# Out:
# Ridu analüüsimiseks: 3298
# apriori min_support: 0.05
#      support                              itemsets  \
# 1   0.430867  ((ADVMOD, , , ))
# 9   0.255609  ((OBL, gen, ,  üle))
# 11  0.171619  ((OBL, kom, , ))
# 3   0.154639  ((AUX, , ei, ))
# 2   0.134930  ((AUX, , , ))
# 13  0.116434  ((OBL, gen, ,  üle), (ADVMOD, , , ))
# 7   0.077016  ((OBL, ad, , ))
# 0   0.074287  ((ADVCL, , , ))
# 10  0.062159  ((OBL, in, , ))
# 5   0.061552  ((OBJ, gen, , ))
# 12  0.058217  ((AUX, , , ), (ADVMOD, , , ))
# 14  0.057914  ((OBL, kom, , ), (ADVMOD, , , ))
# 8   0.056398  ((OBL, gen, ,  vastu))
# 4   0.056095  ((CCOMP, , , ))
# 6   0.051850  ((OBJ, nom, , ))
#
#                                itemlists               example1  \
# 1   [(ADVMOD, , , )]                      tegelikult
# 9   [(OBL, gen, ,  üle)]                  selle  üle
# 11  [(OBL, kom, , )]                      renega
# 3   [(AUX, , ei, )]                       ei
# 2   [(AUX, , , )]                         ära
# 13  [(OBL, gen, ,  üle), (ADVMOD, , , )]  selle  üle tegelikult
# 7   [(OBL, ad, , )]                       meil
# 0   [(ADVCL, , , )]                       istudes
# 10  [(OBL, in, , )]                       netis
# 5   [(OBJ, gen, , )]                      konkurendi
# 12  [(ADVMOD, , , ), (AUX, , , )]         rühmiti oli
# 14  [(OBL, kom, , ), (ADVMOD, , , )]      politseiga siis
# 8   [(OBL, gen, ,  vastu)]                isa  vastu
# 4   [(CCOMP, , , )]                       meeldi
# 6   [(OBJ, nom, , )]                      mis
#
#                example2            example3
# 1   nii                  vahel
# 9   selle  üle           kohaldamise  üle
# 11  kohtunikuga          erkiga
# 3   ei                   ei
# 2   ärge                 ärgem
# 13  põhimõtete  üle ju   nimetuse  üle nüüd
# 7   teemal               poolel
# 0   pea                  tead
# 10  tartus               konvendis
# 5   kriminaalkoodeksi    vaidlemise
# 12  siiamaani oleme      palju on
# 14  perearstiga ükskord  üksteisega küll
# 8   selle  vastu         otsuste  vastu
# 4   suudab               tuleks
# 6   mis                  eiki

# %%
# filtreerud apriori tulemus
df_apriori = v33.filter_apriori_results(df_apriori_unfiltered)
df_apriori
# Out:
#      support                              itemsets  \
# 1   0.430867  ((ADVMOD, , , ))
# 9   0.255609  ((OBL, gen, ,  üle))
# 11  0.171619  ((OBL, kom, , ))
# 3   0.154639  ((AUX, , ei, ))
# 2   0.134930  ((AUX, , , ))
# 13  0.116434  ((OBL, gen, ,  üle), (ADVMOD, , , ))
# 7   0.077016  ((OBL, ad, , ))
# 0   0.074287  ((ADVCL, , , ))
# 10  0.062159  ((OBL, in, , ))
# 5   0.061552  ((OBJ, gen, , ))
# 12  0.058217  ((AUX, , , ), (ADVMOD, , , ))
# 14  0.057914  ((OBL, kom, , ), (ADVMOD, , , ))
# 8   0.056398  ((OBL, gen, ,  vastu))
# 4   0.056095  ((CCOMP, , , ))
# 6   0.051850  ((OBJ, nom, , ))
#
#                                itemlists               example1  \
# 1   [(ADVMOD, , , )]                      tegelikult
# 9   [(OBL, gen, ,  üle)]                  selle  üle
# 11  [(OBL, kom, , )]                      renega
# 3   [(AUX, , ei, )]                       ei
# 2   [(AUX, , , )]                         ära
# 13  [(OBL, gen, ,  üle), (ADVMOD, , , )]  selle  üle tegelikult
# 7   [(OBL, ad, , )]                       meil
# 0   [(ADVCL, , , )]                       istudes
# 10  [(OBL, in, , )]                       netis
# 5   [(OBJ, gen, , )]                      konkurendi
# 12  [(ADVMOD, , , ), (AUX, , , )]         rühmiti oli
# 14  [(OBL, kom, , ), (ADVMOD, , , )]      politseiga siis
# 8   [(OBL, gen, ,  vastu)]                isa  vastu
# 4   [(CCOMP, , , )]                       meeldi
# 6   [(OBJ, nom, , )]                      mis
#
#                example2            example3   drop drop_reason  length
# 1   nii                  vahel               False              1
# 9   selle  üle           kohaldamise  üle    False              1
# 11  kohtunikuga          erkiga              False              1
# 3   ei                   ei                  False              1
# 2   ärge                 ärgem               False              1
# 13  põhimõtete  üle ju   nimetuse  üle nüüd  False              2
# 7   teemal               poolel              False              1
# 0   pea                  tead                False              1
# 10  tartus               konvendis           False              1
# 5   kriminaalkoodeksi    vaidlemise          False              1
# 12  siiamaani oleme      palju on            False              2
# 14  perearstiga ükskord  üksteisega küll     False              2
# 8   selle  vastu         otsuste  vastu      False              1
# 4   suudab               tuleks              False              1
# 6   mis                  eiki                False              1

# %%
v33.draw_heatmap(df_apriori)

# %%
# kõik vaidlema transaktsioonid apriori algoritmile sobival kujul
all_transactions = v33.get_transactions(verb="vaidlema", verb_compound="üle")
# v33._raw_transactions sisemuutujas on salvestatud kõik need transaktsioonid kohendamata kujul
# küll on seal feature, et 'form' asemel on 'frequent_form'
display(all_transactions[list(all_transactions.keys())[0]])
# kui on vaja lisaandmeid, neid saab sama id järgi kätte siit
display(v33._raw_transactions[list(all_transactions.keys())[0]])
# Out:
# [{'deprel': 'NSUBJ', 'case': 'nom', 'frequent_form': '', 'obl_case': ''},
#  {'deprel': 'OBJ', 'case': 'part', 'frequent_form': '', 'obl_case': ''},
#  {'deprel': 'OBL', 'case': 'ad', 'frequent_form': '', 'obl_case': ''}]
# [{'deprel': 'NSUBJ',
#   'case': 'nom',
#   'feats': 'com,nom,pl',
#   'lemma': 'presidendikandidaat',
#   'frequent_form': 'presi-dendikandidaadid',
#   'obl_case': '',
#   'loc': 13},
#  {'deprel': 'OBJ',
#   'case': 'part',
#   'feats': 'part,sg',
#   'lemma': 'üksteise',
#   'frequent_form': 'üksteist',
#   'obl_case': '',
#   'loc': 14},
#  {'deprel': 'OBL',
#   'case': 'ad',
#   'feats': 'ad,com,sg',
#   'lemma': 'tele-debatt',
#   'frequent_form': 'tele-debatil',
#   'obl_case': '',
#   'loc': 15}]
