# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

from estnltk_neural.taggers.syntax.stanza_tagger.stanza_tagger import StanzaSyntaxTagger
from estnltk import Text
from estnltk.storage.postgres import PostgresStorage

# %%
model_path = r"...\estnltk\taggers\syntax\stanza_tagger\stanza_resources"
input_type="morph_extended"
stanza_tagger = StanzaSyntaxTagger(input_type=input_type, input_morph_layer=input_type, add_parent_and_children=True, resources_path=model_path)

# %% [markdown]
# ## EntityTagger (need spanid, mis eemaldati)

# %%
from scripts.entity_tagger import EntityTagger

entity_tagger = EntityTagger(deprel ="advmod", input_type="stanza_syntax", morph_layer="morph_extended")

# %%
txt3 = Text("Võtete ajal õppis Eminem lugu pidama näitlejatest , kes suhtuvad oma töösse sama tõsiselt kui tema muusikasse .")
txt3.tag_layer('morph_extended')
stanza_tagger.tag( txt3 )
entity_tagger.tag( txt3 )
txt3.stanza_syntax_ignore_entity
# Out:
# Layer(name='stanza_syntax_ignore_entity', attributes=('entity_type', 'free_entity', 'is_valid'), spans=SL[EnvelopingSpan(['tõsiselt', 'kui', 'tema', 'muusikasse'], [{'entity_type': None, 'free_entity': None, 'is_valid': None}])])

# %% [markdown]
# ## StanzaSyntaxIgnoreTagger (lühendatud lause uute deprelitega + "eemaldatud" alampuu id ja head on None)

# %%
from scripts.stanza_syntax_ignore_tagger import StanzaSyntaxIgnoreTagger

ignore_tagger = StanzaSyntaxIgnoreTagger( input_type="morph_extended", input_morph_layer="morph_extended", 
                                                      add_parent_and_children=True, resources_path=model_path)

# %%
ignore_tagger.tag( txt3 )
txt3.stanza_syntax_without_entity
# Out:
# Layer(name='stanza_syntax_without_entity', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'status', 'parent_span', 'children'), spans=SL[Span('Võtete', [{'id': 1, 'lemma': 'võte', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 3, 'deprel': 'obl', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('ajal', [{'id': 2, 'lemma': 'ajal', 'upostag': 'K', 'xpostag': 'K', 'feats': OrderedDict([('post', 'post')]), 'head': 1, 'deprel': 'case', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# ...

# %% [markdown]
# ## WithRemoveDeprelTagger (lühendatud lause uute deprelite + eemaldatud spanid negatiivsete id-ga)

# %%
#from scripts.StanzaSyntaxWithRemoveDeprelTagger import StanzaSyntaxWithRemoveDeprelTagger

# %%
#input_type="morph_extended"
#deprel_with_remove_tagger = StanzaSyntaxWithRemoveDeprelTagger(stanza_tagger = stanza_tagger, 
#                                                      input_type=input_type, input_morph_layer="morph_extended", 
#                                                      add_parent_and_children=True, resources_path=model_path)

# %%
#deprel_with_remove_tagger.tag( txt3 )
#txt3.stanza_syntax_with_remove_deprel
# Out:
# Layer(name='stanza_syntax_with_remove_deprel', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'status', 'parent_span', 'children'), spans=SL[Span('Võtete', [{'id': 1, 'lemma': 'võte', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('pl', 'pl'), ('gen', 'gen')]), 'head': 3, 'deprel': 'obl', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# Span('ajal', [{'id': 2, 'lemma': 'ajal', 'upostag': 'K', 'xpostag': 'K', 'feats': OrderedDict([('post', 'post')]), 'head': 1, 'deprel': 'case', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# ...

# %% [markdown]
# ## Katse teise lausega (pole eemaldatud alampuud)

# %%
from scripts.entity_tagger import EntityTagger

from scripts.stanza_syntax_ignore_tagger import StanzaSyntaxIgnoreTagger

# %%
entity_tagger = EntityTagger(deprel ="advmod", input_type="stanza_syntax", morph_layer="morph_extended")

ignore_tagger = StanzaSyntaxIgnoreTagger( input_type="morph_extended", input_morph_layer="morph_extended", 
                                                      add_parent_and_children=True, resources_path=model_path)

# %%
txt4 = Text("Filmi lõppedes jääb tunne , et unistus saab teoks .")
txt4.tag_layer('morph_extended')
stanza_tagger.tag( txt4 )
#txt4.tag_layer('stanza_syntax')
entity_tagger.tag( txt4 )
txt4.stanza_syntax_ignore_entity
# Out:
# Layer(name='stanza_syntax_ignore_entity', attributes=('entity_type', 'free_entity', 'is_valid'), spans=SL[])

# %%
#txt4.tag_layer('stanza_syntax')
ignore_tagger.tag( txt4 )
txt4.stanza_syntax_without_entity
# Out:
# Layer(name='stanza_syntax_without_entity', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'status', 'parent_span', 'children'), spans=SL[Span('Filmi', [{'id': 1, 'lemma': 'film', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('gen', 'gen')]), 'head': 2, 'deprel': 'obl', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('lõppedes', [{'id': 2, 'lemma': 'lõppema', 'upostag': 'V', 'xpostag': 'V', 'feats': OrderedDict([('aux', 'aux'), ('ger', 'ger')]), 'head': 3, 'deprel': 'advcl', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# ...

# %% [markdown]
# ## Katse kolmanda lausega

# %%
from scripts.entity_tagger import EntityTagger

entity_tagger = EntityTagger(deprel ="advmod", input_type="stanza_syntax", morph_layer="morph_extended")

# %%
from scripts.stanza_syntax_ignore_tagger import StanzaSyntaxIgnoreTagger

ignore_tagger = StanzaSyntaxIgnoreTagger( input_type="morph_extended", input_morph_layer="morph_extended", 
                                                      add_parent_and_children=True, resources_path=model_path)

# %%
txt5 = Text("Kolme aastaga on Eminem alias Marshall Mathers III ( 30 ) kindlalt meie teadvusesse sööbinud .")
txt5.tag_layer('morph_extended')
stanza_tagger.tag( txt5 )

entity_tagger.tag( txt5 )
txt5.stanza_syntax_ignore_entity
# Out:
# Layer(name='stanza_syntax_ignore_entity', attributes=('entity_type', 'free_entity', 'is_valid'), spans=SL[EnvelopingSpan(['kindlalt'], [{'entity_type': None, 'free_entity': None, 'is_valid': None}])])

# %%
ignore_tagger.tag( txt5 )
txt5.stanza_syntax_without_entity
# Out:
# Layer(name='stanza_syntax_without_entity', attributes=('id', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc', 'status', 'parent_span', 'children'), spans=SL[Span('Kolme', [{'id': 1, 'lemma': 'kolm', 'upostag': 'N', 'xpostag': 'N', 'feats': OrderedDict([('card', 'card'), ('sg', 'sg'), ('gen', 'gen'), ('l', 'l')]), 'head': 2, 'deprel': 'nummod', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': ()}]),
# Span('aastaga', [{'id': 2, 'lemma': 'aasta', 'upostag': 'S', 'xpostag': 'S', 'feats': OrderedDict([('com', 'com'), ('sg', 'sg'), ('kom', 'kom')]), 'head': 14, 'deprel': 'obl', 'deps': '_', 'misc': '_', 'status': 'remained', 'parent_span': <class 'estnltk_core.layer.span.Span'>, 'children': <class 'tuple'>}]),
# ...
