# %% [markdown]
# # Kas süntaks on konserveerunud 10 000 juh advmod lauset

# %% [markdown]
# Loeme failist 10 000 juhuslikku lauset

# %%
import csv
import pandas as pd
import json

# %% [markdown]
# Loeme laused failist.

# %%
sentencesTSV = 'result/1_sentences_with_advmod.tsv'

df = pd.read_csv(sentencesTSV, sep='\t', header=None, quoting=csv.QUOTE_NONE)  
df.shape
# Out:
# (10626918, 3)

# %%
df.head()
# Out:
#    0     1                                                  2
# 0  0    69  Endine punkar , tulevane lendur , karateka ja ...
# 1  0   262  Bändi , mille solist ei osanud laulda , kidram...
# 2  0   739  Kui sageli tuli sul kooli juhtkonna ees aru an...
# 3  0   791  Mind kutsuti tihti direktori jutule , aga mitt...
# 4  0  1080  Tol ajal oli mu ainuke prioriteet muusika , mi...

# %% [markdown]
# Ajame read juhuslikku järjekorda

# %%
def shuffle_rows(df):
    return df.sample(frac=1).reset_index(drop=True)

df = shuffle_rows(df)
df.head()
# Out:
#         0        1                                                  2
# 0  690671     1338                         Lavalt tuli ainult kulda .
# 1  655256     2286                       Kuskilt live-feed ka tuleb ?
# 2  640616  1937228   Kui nii näis siis palun ka avalikult vabandust .
# 3  700938   303798  võibolla on mul tõesti midagi kahe silma vahel...
# 4  405340     2920  Ööpoed müüvad öösiti vaid konserve ja vorsti ,...

# %% [markdown]
# ### 10 000 esimest juhuslikku lauset
#
# Laseme süntaksi peale
# Eemaldame admvod koos selle alampuuga
# Kontrollime, kas süntaks on konserveerunud

# %%
import stanza
import os
from estnltk import Text
from estnltk.taggers.syntax.stanza_tagger.stanza_tagger import StanzaSyntaxTagger
from estnltk.converters.conll_exporter import  sentence_to_conll
import numpy as np

# %%
model_path = ".../estnltk-version_1.6/estnltk/taggers/syntax/stanza_tagger/stanza_resources"
model_path = '/Users/rabauti/stanza-models/stanza_recources'
input_type="morph_extended"
#stanza_tagger = StanzaSyntaxTagger(input_type=input_type, input_morph_layer=input_type, resources_path=model_path)
stanza_tagger = StanzaSyntaxTagger(input_type=input_type, input_morph_layer=input_type, add_parent_and_children=True, resources_path=model_path)

# %%
def write_to_file(t, f):
    f.write(t)

def get_children(span, lst):
    if not span.children:
        return
    else:
        for child in span.children:
            lst += [int(child.id)-1]
            get_children(child, lst)


def remove_deprel(sentence, dprl, stanza_tagger):
    changes = {}
    no_rem_dprls = 0
   
    #Lausete lühendamine
    sent = sentence.sentences.text
    len_sent = len(sent)
    lsts = []
    for span in sentence.stanza_syntax:
        if span.deprel == dprl:
            lst = [int(span.id)-1]
            get_children(span, lst)
            lsts += lst

    sent = np.array(sent)
    sent[list(set(lsts))] = ":::"
    sent = list(sent)
    sent = list(filter(lambda a: a != ":::", sent))
    if  len(sent) != len_sent:
       
        no_rem_dprls += (len_sent - len(sent))
    
    short_sent = " ".join(sent)
    short_sent = short_sent[0].upper() + short_sent[1:]
    short_sent_txt = Text(short_sent)
    short_sent_txt.analyse('all')
    stanza_tagger.tag(short_sent_txt)
    len_short_sent = len(sent)
    
    pikkus = 0
    e = 0
    m = 0

    sent_deprel = ''
    changed = False
    while len_sent > pikkus:
        sp_long = sentence.stanza_syntax[pikkus]
        if  e < len_short_sent:
            sp_short = short_sent_txt.stanza_syntax[e]
        
        if sp_short.text.lower() == sp_long.text.lower() and pikkus == e + m and e < len_short_sent:
            sent_deprel += sp_short["deprel"] + " "
            if sp_short["deprel"] != sp_long.deprel:
                changed = True
                key = sp_long.deprel + "_" + sp_short["deprel"]
                if key not in changes.keys():
                    changes[key] = 1
                else:
                    changes[key] += 1
            e += 1
        else:
            sent_deprel += "_" + " "
            m += 1
        pikkus += 1     
    
    # changed - kas muutus
    # short_sent_txt.stanza_syntax
    # no_rem_dprls, changes
    return {'changed': changed \
                , 'short_sent_txt': short_sent_txt \
                , 'no_rem_dprls': no_rem_dprls \
                , 'changes': changes \
                , 'sent_deprel': sent_deprel}

# %% [markdown]
# Leiame 10 korda statistika 10000 juhusliku lause kohta, milles esines deprel *advmod*.
#     * mitmes lauses süntaks konserveerub,
#     * mitmes lauses süntaks ei konserveeru.
#
# Salvestame need läbivaadatud laused failidesse, et saaks vajadusel kontrollida.

# %%
# %%time

# deprel to remove
dprl = "advmod"

RESULTS_PATH = "./result/"


count = 10000
iterations = 2


stats = {'iteration': []
             , 'total_sentences': []
             , 'syntax_changed': []
             , 'syntax_conserved': []
             , 'allchanges': []
        }
for i in range(iterations):    
    iteration = i+1
    df = shuffle_rows(df)
    print (f"Iteratsioon {iteration}")
    sentencesFilename = f"{RESULTS_PATH}2_sentences_{dprl}_set_{iteration}.tsv"
   
    sentencesF = open(sentencesFilename, 'w', encoding='utf-8')
   
    # create the csv writer
    wSentences = csv.writer(sentencesF, delimiter='\t')
  


    wSentences.writerow(('collectionID', 'sentenceStart', 'changed', 'changes', 'original', 'short',))
    
    proc_txt_no = 0 # counter for texts
    no_rem_dprlss = 0   # count number of removed deprels
    no_changed_syntaxs = 0   # count sentences where syntax changed

    sentences_count = 0
    syntax_conserved = 0
    syntax_changed = 0

    all_changes = {}

    for ind in range(df.shape[0]):
        #ignoreerime lauseid, kus pole advmod'i siiski sees

        proc_txt_no = df[0][ind]
        sent_span_start = df[1][ind]

        txt = df[2][ind]
        #print (txt)
        sent = stanza_tagger.tag(Text(txt).analyse("all"))

        # siia kontroll, et advmod ikka sees
        if not dprl in sent.deprel: continue

        sentences_count += 1
        result = remove_deprel(sent, dprl, stanza_tagger)
        if not len(result['changes']):
            syntax_conserved +=1
        else:
            syntax_changed +=1
        
        all_changes = {k: all_changes.get(k, 0) + result['changes'].get(k, 0) for k in set(all_changes) | set(result['changes'])}
       
        wSentences.writerow( [str(proc_txt_no) \
                , str(sent_span_start) \
                , str(int(result['changed'] == True)) \
                , json.dumps(result['changes']) \
                , sent.text \
                , result['short_sent_txt'].text  ], )
       

        if sentences_count >= count: break 
    
    sentencesF.close()

    stats['iteration'].append(iteration)
    stats['syntax_changed'].append(syntax_changed)
    stats['syntax_conserved'].append(syntax_conserved)
    stats['total_sentences'].append(sentences_count)
    stats['allchanges'].append(json.dumps(all_changes))
    
    print (f'Teisendatud {sentences_count} lauset.')
    print (f'Kokku vaadati {ind+1} lauset.')
    print (f'Süntaks konserveerunud {syntax_conserved} lausel.')

    print (all_changes)
# Out:
# Iteratsioon 1
# Teisendatud 10000 lauset.
# Kokku vaadati 10129 lauset.
# Süntaks konserveerunud 6540 lausel.
# {'det_nmod': 13, 'ccomp_csubj': 1, 'nmod_advcl': 5, 'compound:prt_conj': 3, 'flat_appos': 3, 'acl_obl': 4, 'xcomp_nmod': 4, 'xcomp_acl:relcl': 2, 'csubj:cop_conj': 8, 'parataxis_conj': 18, 'ccomp_case': 1, 'nsubj:cop_advcl': 4, 'root_nsubj': 46, 'obl_xcomp': 17, 'conj_obj': 27, 'nummod_nsubj': 1, 'mark_cc:preconj': 1, 'ccomp_acl': 18, 'cc_mark': 31, 'cc_aux': 1, 'obl_appos': 12, 'advcl_nsubj': 13, 'csubj_conj': 7, 'root_obj': 14, 'obj_appos': 7, 'acl:relcl_nsubj:cop': 2, 'advcl_aux': 6, 'parataxis_csubj': 1, 'obl_nmod': 252, 'csubj_acl:relcl': 2, 'nsubj:cop_flat': 6, 'obl_nsubj:cop': 11, 'aux_advcl': 7, 'xcomp_nsubj': 4, 'nummod_flat': 2, 'csubj:cop_advcl': 1, 'amod_advcl': 5, 'obl_obj': 93, 'acl_advmod': 1, 'root_csubj': 2, 'amod_nsubj:cop': 1, 'conj_xcomp': 31, 'amod_cop': 3, 'conj_det': 1, 'nmod_amod': 5, 'nsubj:cop_root': 49, 'ccomp_xcomp': 2, 'acl:relcl_aux': 2, 'parataxis_discourse': 1, 'nsubj_nmod': 56, 'csubj:cop_acl:relcl': 1, 'amod_conj': 11, 'root_advcl': 31, 'parataxis_nsubj': 9, 'conj_root': 67, 'conj_acl': 92, 'flat_flat:foreign': 2, 'compound:prt_obl': 1, 'acl:relcl_root': 3, 'mark_obl': 1, 'nmod_ccomp': 1, 'acl_amod': 3, 'parataxis_cc': 1, 'parataxis_vocative': 3, 'acl:relcl_nmod': 2, 'flat:foreign_flat': 2, 'vocative_root': 3, 'csubj_acl': 3, 'obl_conj': 54, 'parataxis_acl': 7, 'appos_flat': 8, 'amod_nsubj': 2, 'nsubj:cop_det': 18, 'amod_obl': 9, 'appos_nmod': 13, 'root_compound:prt': 3, 'case_compound:prt': 25, 'det_obl': 6, 'flat_cc': 3, 'det_obj': 10, 'compound:prt_advcl': 1, 'nsubj:cop_acl': 1, 'advcl_vocative': 3, 'parataxis_root': 66, 'nsubj_ccomp': 4, 'nsubj_nummod': 2, 'nsubj_advcl': 6, 'aux_acl': 3, 'advcl_obl': 28, 'acl:relcl_nummod': 2, 'nsubj:cop_nmod': 42, 'root_vocative': 9, 'advcl_csubj': 10, 'punct_conj': 1, 'csubj_advcl': 1, 'acl_nsubj:cop': 1, 'amod_det': 61, 'obj_acl': 1, 'obj_compound:prt': 1, 'xcomp_orphan': 2, 'advcl_acl:relcl': 4, 'obj_parataxis': 3, 'aux_root': 27, 'conj_ccomp': 17, 'nummod_nsubj:cop': 1, 'obj_xcomp': 2, 'nummod_amod': 1, 'obl_det': 11, 'obl_root': 57, 'root_conj': 69, 'case_root': 1, 'root_advmod': 20, 'root_acl': 84, 'parataxis_nmod': 13, 'csubj_csubj:cop': 6, 'conj_nummod': 3, 'obj_nummod': 2, 'det_ccomp': 1, 'compound:prt_amod': 2, 'xcomp_flat': 2, 'aux_advmod': 8, 'conj_appos': 12, 'acl:relcl_case': 1, 'nsubj_appos': 19, 'ccomp_obl': 8, 'root_parataxis': 52, 'ccomp_cop': 3, 'xcomp_csubj': 5, 'parataxis_obj': 2, 'root_case': 2, 'acl:relcl_conj': 10, 'obj_nmod': 76, 'obj_nsubj:cop': 91, 'amod_obj': 5, 'csubj:cop_xcomp': 8, 'aux_cop': 251, 'nmod_obj': 46, 'flat_punct': 2, 'nsubj_discourse': 1, 'acl:relcl_parataxis': 3, 'conj_nsubj': 24, 'acl_ccomp': 17, 'conj_flat': 3, 'mark_advmod': 46, 'nsubj_parataxis': 8, 'appos_conj': 7, 'acl:relcl_amod': 2, 'advcl_cop': 4, 'acl:relcl_cop': 1, 'advcl_compound:prt': 1, 'xcomp_conj': 22, 'conj_case': 1, 'nmod_parataxis': 7, 'nummod_advmod': 1, 'det_advcl': 1, 'conj_obl': 54, 'obl_compound:prt': 2, 'cop_acl:relcl': 1, 'obj_ccomp': 1, 'root_ccomp': 3, 'appos_obl': 1, 'advcl_nsubj:cop': 4, 'conj_orphan': 5, 'parataxis_advmod': 11, 'aux_acl:relcl': 3, 'acl_obj': 2, 'obj_root': 16, 'nsubj_nsubj:cop': 162, 'conj_compound:prt': 5, 'cop_acl': 11, 'root_nummod': 1, 'conj_mark': 1, 'det_conj': 2, 'case_advmod': 11, 'nmod_xcomp': 2, 'advcl_advmod': 8, 'ccomp_nsubj:cop': 2, 'amod_xcomp': 3, 'acl_appos': 1, 'flat_conj': 3, 'parataxis_flat': 1, 'csubj:cop_root': 2, 'obl_orphan': 1, 'vocative_parataxis': 1, 'acl_acl:relcl': 9, 'xcomp_csubj:cop': 10, 'vocative_flat:foreign': 1, 'discourse_root': 1, 'nmod_acl:relcl': 4, 'mark_cc': 3, 'appos_advcl': 1, 'compound:prt_aux': 2, 'compound:prt_case': 38, 'advcl_root': 53, 'flat_obl': 1, 'nmod_det': 7, 'root_amod': 13, 'cop_aux': 290, 'conj_vocative': 3, 'nsubj_acl': 1, 'amod_acl': 2, 'det_nummod': 83, 'obj_nsubj': 85, 'advcl_acl': 83, 'acl_root': 69, 'nsubj_acl:relcl': 2, 'acl_parataxis': 10, 'root_csubj:cop': 4, 'ccomp_nmod': 6, 'punct_flat': 1, 'root_appos': 1, 'nsubj:cop_ccomp': 6, 'appos_root': 2, 'a ...
# Iteratsioon 2
# Teisendatud 10000 lauset.
# Kokku vaadati 10110 lauset.
# Süntaks konserveerunud 6502 lausel.
# {'det_nmod': 13, 'ccomp_csubj': 2, 'nmod_advcl': 5, 'nmod_nummod': 1, 'flat_appos': 2, 'acl_obl': 3, 'xcomp_nmod': 2, 'xcomp_acl:relcl': 2, 'appos_nsubj:cop': 3, 'csubj:cop_conj': 17, 'parataxis_conj': 15, 'punct_parataxis': 1, 'nsubj:cop_advcl': 5, 'root_nsubj': 32, 'obl_xcomp': 14, 'aux_cc': 2, 'conj_obj': 39, 'acl_nsubj': 4, 'nummod_nsubj': 1, 'ccomp_acl': 15, 'cc_mark': 38, 'root_mark': 1, 'obl_appos': 5, 'advcl_nsubj': 11, 'csubj_conj': 7, 'root_obj': 19, 'obj_appos': 2, 'acl:relcl_nsubj:cop': 1, 'advcl_aux': 4, 'parataxis_csubj': 1, 'mark_nmod': 2, 'obl_nmod': 297, 'nsubj:cop_flat': 1, 'obl_nsubj:cop': 19, 'csubj:cop_advcl': 8, 'aux_advcl': 5, 'nummod_flat': 5, 'xcomp_nsubj': 1, 'amod_advcl': 6, 'obl_obj': 76, 'acl_advmod': 1, 'root_csubj': 1, 'appos_vocative': 1, 'conj_xcomp': 32, 'nmod_amod': 5, 'conj_det': 5, 'amod_cop': 1, 'nsubj:cop_root': 42, 'ccomp_xcomp': 3, 'flat_nsubj:cop': 1, 'acl:relcl_aux': 4, 'nsubj_nmod': 73, 'amod_conj': 10, 'csubj:cop_acl:relcl': 1, 'root_advcl': 38, 'parataxis_nsubj': 7, 'conj_root': 82, 'conj_acl': 74, 'flat_flat:foreign': 3, 'root_discourse': 1, 'nmod_mark': 1, 'compound:prt_obl': 7, 'compound:prt_acl:relcl': 1, 'acl:relcl_root': 1, 'mark_obl': 1, 'acl_amod': 5, 'acl:relcl_nmod': 1, 'parataxis_vocative': 3, 'vocative_root': 1, 'flat:foreign_flat': 4, 'csubj_acl': 11, 'obl_conj': 46, 'parataxis_acl': 15, 'appos_flat': 11, 'amod_nsubj': 6, 'xcomp_aux': 1, 'nsubj:cop_det': 7, 'nsubj:cop_vocative': 2, 'amod_obl': 12, 'appos_nmod': 12, 'root_compound:prt': 6, 'case_compound:prt': 23, 'det_obl': 7, 'cc_conj': 1, 'flat_cc': 1, 'det_obj': 7, 'compound:prt_advcl': 1, 'nsubj:cop_acl': 2, 'parataxis_root': 63, 'nsubj_ccomp': 2, 'nsubj_nummod': 3, 'nsubj_advcl': 4, 'aux_acl': 5, 'nummod_case': 1, 'advcl_obl': 25, 'advcl_csubj': 15, 'nsubj:cop_nmod': 30, 'root_vocative': 6, 'csubj_advcl': 6, 'acl_nsubj:cop': 1, 'nummod_parataxis': 1, 'amod_det': 51, 'obj_acl': 1, 'xcomp_orphan': 1, 'advcl_acl:relcl': 4, 'obj_parataxis': 4, 'conj_ccomp': 15, 'aux_root': 28, 'nummod_nmod': 1, 'obj_xcomp': 3, 'nummod_amod': 1, 'obl_det': 7, 'obl_root': 61, 'root_conj': 88, 'case_root': 1, 'root_advmod': 20, 'root_acl': 98, 'parataxis_nmod': 12, 'csubj_csubj:cop': 2, 'xcomp_appos': 1, 'conj_nummod': 5, 'aux_csubj:cop': 1, 'obj_nummod': 4, 'vocative_obj': 1, 'aux_advmod': 10, 'conj_appos': 11, 'nsubj_appos': 19, 'ccomp_obl': 10, 'root_parataxis': 39, 'xcomp_csubj': 6, 'parataxis_obj': 7, 'mark_fixed': 1, 'root_case': 5, 'acl:relcl_conj': 10, 'obj_nmod': 85, 'obj_nsubj:cop': 91, 'amod_obj': 3, 'csubj:cop_xcomp': 9, 'aux_cop': 270, 'nmod_obj': 46, 'orphan_cc': 1, 'flat_punct': 1, 'parataxis_det': 1, 'acl:relcl_parataxis': 2, 'conj_nsubj': 11, 'acl:relcl_ccomp': 1, 'acl_ccomp': 10, 'conj_flat': 4, 'mark_advmod': 37, 'nsubj_parataxis': 10, 'appos_conj': 6, 'acl:relcl_amod': 3, 'advcl_cop': 6, 'acl:relcl_cop': 2, 'xcomp_conj': 27, 'conj_case': 2, 'nummod_advmod': 1, 'appos_obl': 7, 'nmod_parataxis': 15, 'obj_ccomp': 3, 'obl_compound:prt': 4, 'conj_obl': 61, 'nsubj:cop_orphan': 1, 'cop_acl:relcl': 4, 'csubj_advmod': 1, 'root_ccomp': 3, 'advcl_nsubj:cop': 4, 'nsubj_csubj': 1, 'conj_orphan': 5, 'parataxis_advmod': 4, 'acl_obj': 1, 'aux_acl:relcl': 1, 'obj_root': 29, 'nsubj_nsubj:cop': 184, 'conj_compound:prt': 4, 'cop_acl': 10, 'root_nummod': 2, 'csubj:cop_obj': 1, 'det_conj': 1, 'case_advmod': 8, 'nmod_xcomp': 6, 'advcl_advmod': 6, 'ccomp_nsubj:cop': 4, 'amod_xcomp': 5, 'parataxis_aux': 5, 'flat_conj': 3, 'parataxis_flat': 6, 'aux_nsubj': 1, 'csubj:cop_root': 6, 'appos_nummod': 1, 'flat_obj': 1, 'vocative_parataxis': 1, 'acl_acl:relcl': 9, 'xcomp_csubj:cop': 5, 'compound:prt_aux': 2, 'appos_advcl': 2, 'mark_cc': 5, 'nmod_acl:relcl': 1, 'compound:prt_case': 28, 'obl_vocative': 1, 'advcl_root': 67, 'obl_mark': 1, 'flat_obl': 3, 'nmod_det': 9, 'root_amod': 13, 'cop_aux': 262, 'conj_vocative': 8, 'nsubj_acl': 2, 'vocative_appos': 1, 'obj_nsubj': 82, 'det_nummod': 66, 'advcl_acl': 92, 'amod_acl': 5, 'acl_root': 74, 'nsubj_acl:relc ...
# CPU times: user 37min 56s, sys: 1min 38s, total: 39min 35s
# Wall time: 39min 31s

# %%
dfStat = pd.DataFrame(stats)
dfStat.to_csv(f"{RESULTS_PATH}2_{dprl}_stats.tsv",sep='\t', index=False)

# %%
dfChanged = pd.read_csv(sentencesFilename, sep='\t', quotechar = '"')  
dfChanged.shape
# Out:
# (10000, 6)

# %%
dfChanged.sample(10)
# Out:
#       collectionID  sentenceStart  changed  \
# 2723        519470           1339        1
# 1466        281940            920        0
# 971         514774          13694        0
# 3387          6336            126        0
# 3758        615707           1437        0
# 8459        646648            692        0
# 1346        647835           1392        0
# 9320        705041          49740        0
# 3440        381325           4890        0
# 9842        681223           1671        1
#
#                                                 changes  \
# 2723  {"root_nmod": 1, "nsubj_appos": 1, "obj_root": 1}
# 1466                                                 {}
# 971                                                  {}
# 3387                                                 {}
# 3758                                                 {}
# 8459                                                 {}
# 1346                                                 {}
# 9320                                                 {}
# 3440                                                 {}
# 9842  {"cc_advmod": 1, "nsubj_nmod": 1, "nmod_flat": 1}
#
#                                                                                                                                                                           original  \
# 2723                                                                                          Mullu testisid Korjus-Jakk MTH mootoreid ning said võistlusteks tasuta jõuallikaid .
# 1466                                                                                                                                  Ja ometi pole Malèna lõpuni lahtiharutatud .
# 971                                                                                                              Tollal oli teatavasti raske mis tahes alkohoolset jooki soetada .
# 3387  Samu andmeid kinnitas ka Ingušimaa president Ruslan Aušev , kelle sõnul peidavad inimesed ennast keldrites ega saa linnast lahkuda , kuna pole mingeid transpordivahendeid .
# 3758                                Eelnevast lähtuvalt üritatakse avalikkusele jätta mulje , et küll me toimetame siin vaikselt ja tagasihoidlikult ning ega me eriti ei kuluta .
# 8459                                                                      Kui jätta kõrvale paari üksiku talu tragöödia , ei ole kaugemalt vaadates praegusel piiril häda midagi .
# 1346                                                                                                                                    Mingisugust auto-adjust nuppu ei ole või ?
# 9320   Kõik kolm valitsust on väljendanud oma soovi jõustada leping hiljemalt 31. oktoobriks käesoleval aastal , mis eeldaks viimase ratifitseerimisteate saabumist 31. augustil .
# 3440                                                                                                                           Ja veel : äris kehtib reegel , et hulgi on odavam .
# 9842              ja neljandax iga soliidne yrituse korraldaja ( kui mitte soliidne , siis seda enam on vaja ) mainix ka zyrii koosseisu , mitte nii et lihtsalt mingi 4 inimest .
#
#                                                                                                                                                                           short
# 2723                                                                                             Testisid Korjus-Jakk MTH mootoreid ning said võistlusteks tasuta jõuallikaid .
# 1466                                                                                                                                     Ja pole Malèna lõpuni lahtiharutatud .
# 971                                                                                                                                       Oli raske alkohoolset jooki soetada .
# 3387  Samu andmeid kinnitas Ingušimaa president Ruslan Aušev , kelle sõnul peidavad inimesed ennast keldrites ega saa linnast lahkuda , kuna pole mingeid transpordivahendeid .
# 3758                                                                                                  Üritatakse avalikkusele jätta mulje , et me toimetame ning me ei kuluta .
# 8459                                                                             Kui jätta kõrvale paari üksiku talu tragöödia , ei ole vaadates praegusel piiril häda midagi .
# 1346                                                                                                                                     Mingisugust auto-adjust nuppu ei ole ?
# 9320          Kõik kolm valitsust on väljendanud oma soovi jõustada leping 31. oktoobriks käesoleval aastal , mis eeldaks viimase ratifitseerimisteate saabumist 31. augustil .
# 3440                                                                                                                                        : äris kehtib reegel , et on odavam
# 9842                                                    Ja neljandax iga soliidne yrituse korraldaja ( kui soliidne , siis on vaja ) mainix zyrii koosseisu , mingi 4 inimest .
