# %%
import sys
sys.path.append("..\\")

# %%
from estnltk_patches.label_studio.labelling_configurations.phrase_tagging_configuration import PhraseTaggingConfiguration
from estnltk_patches.label_studio.labelling_tasks.phrase_tagging_task import PhraseTaggingTask

from estnltk_patches.label_studio.labelling_configurations.phrase_classification_configuration import PhraseClassificationConfiguration
from estnltk_patches.label_studio.labelling_tasks.phrase_classification_task import PhraseClassificationTask

# %%
from estnltk import Text
from estnltk.taggers.system.rule_taggers.extraction_rules.ruleset import AmbiguousRuleset, Ruleset
from estnltk.taggers.system.rule_taggers.extraction_rules.static_extraction_rule import StaticExtractionRule
from estnltk.taggers.system.rule_taggers.taggers.substring_tagger import SubstringTagger
import sqlite3

# %%
rules = Ruleset([
    StaticExtractionRule('kass', {'label': 'kass'}),
    StaticExtractionRule('koer', {'label': 'koer'})
])

tagger = SubstringTagger(rules, output_attributes=['label'], ignore_case=True)

# %%
text = Text('Koer tuletas omanikule meelde, et uus kass, mille peremees võtab, ei tohi olla ilusam kui vana')
tagger(text)
None

# %%
conf = PhraseTaggingConfiguration(['Koer', 'kass'])
task = PhraseTaggingTask(conf, input_layer='terms', output_layer='terms', labelling_function=lambda x: x.text)

# %%
print(task.interface_file)
# Out:
# <View>
#   <Labels name="terms" toName="text" >
#     <Label value="Koer" background="green" />
#     <Label value="kass" background="blue" />
#   </Labels>
#   <Text name="text" value="$text" granularity="word" />
# </View>

# %%
print(task.export_data(text, indent=2))
assert task.exported_labels == {'Koer', 'kass'}
# Out:
# [
#   {
#     "data": {
#       "text": "Koer tuletas omanikule meelde, et uus kass, mille peremees v\u00f5tab, ei tohi olla ilusam kui vana"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 4,
#               "labels": [
#                 "Koer"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           },
#           {
#             "value": {
#               "start": 38,
#               "end": 42,
#               "labels": [
#                 "kass"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   }
# ]

# %% [markdown]
# ### On more data

# %%
# getting data from database
con = sqlite3.connect("tagged_noun_phrases2.db")
cur = con.cursor()

# %%
cur.execute("SELECT extraction_pattern, ner_pattern, raw_text, raw_lemmas, count(*) FROM tagged_phrases GROUP BY raw_lemmas ORDER BY count(*) DESC")
data = cur.fetchall()

# %%
data[0]
# Out:
# ('1 2 nmod,2 0 root,3 2 nmod,H-S-S',
#  'LOC-OTHER-OTHER',
#  'Euroopa tunnetamises koduna',
#  'Euroopa tunnetamine kodu',
#  33)

# %%
con.close()

# %%
rules_list = []

for row in data:
    syntax_tree = ','.join(row[0].split(',')[:-1])
    pos_pattern = row[0].split(',')[-1]
    rule = StaticExtractionRule(row[3], {'syntax_tree_pattern': syntax_tree, 'POS_pattern': pos_pattern, 'NER_pattern': row[1], 'raw_text': row[2]})
    #print(rule.output_attributes)
    rules_list.append(rule)

# %%
rules = AmbiguousRuleset(rules_list)
tagger = SubstringTagger(rules, output_attributes=['syntax_tree_pattern', 'POS_pattern', 'NER_pattern', 'raw_text'], ignore_case=True)

# %%
print(data[0])
# Out:
# ('1 2 nmod,2 0 root,3 2 nmod,H-S-S', 'LOC-OTHER-OTHER', 'Euroopa tunnetamises koduna', 'Euroopa tunnetamine kodu', 33)

# %%
data = [list(row) for row in data]

# %%
texts = []

for row in data:
    row[3] = Text(row[3])
    tagger.tag(row[3])
    texts.append(row[3])
    None

# %%
display(texts[0].terms)
# Out:
# Layer(name='terms', attributes=('syntax_tree_pattern', 'POS_pattern', 'NER_pattern', 'raw_text'), spans=SL[Span('Euroopa tunnetamine kodu', [{'syntax_tree_pattern': '1 2 nmod,2 0 root,3 2 nmod', 'POS_pattern': 'H-S-S', 'NER_pattern': 'LOC-OTHER-OTHER', 'raw_text': 'Euroopa tunnetamises koduna'}])])

# %%
conf = PhraseTaggingConfiguration(['syntax_tree_pattern', 'POS_pattern', 'NER_pattern'])
task = PhraseTaggingTask(conf, input_layer='terms', output_layer='terms', label_attribute='NER_pattern')

# %%
print(task.interface_file)
# Out:
# <View>
#   <Labels name="terms" toName="text" >
#     <Label value="syntax_tree_pattern" background="#1b9e77" />
#     <Label value="POS_pattern" background="#d95f02" />
#     <Label value="NER_pattern" background="#7570b3" />
#   </Labels>
#   <Text name="text" value="$text" granularity="word" />
# </View>

# %%
print(task.exported_labels)
# Out:
# set()

# %%
print(task.export_data(texts[0], indent=2))
# Out:
# [
#   {
#     "data": {
#       "text": "Euroopa tunnetamine kodu"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "LOC-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   }
# ]

# %%
print(task.export_data(texts, indent=2))
# Out:
# [
#   {
#     "data": {
#       "text": "Euroopa tunnetamine kodu"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "LOC-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Euroopa tunnetamine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ca 5%"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 5,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Balti riik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "N\u00f5ukogu Liit"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "\u00dchendriik t\u00f6\u00f6stusspionaazh"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 26,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "t\u00f6\u00f6stusspionaazh Euroopa"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "elu seotud teema"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "riigikontroll kontroll pank"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 27,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "riigikontroll kontroll"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 22,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eesti keel"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Euroopa Liit"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suurim s\u00f5idukiirus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suhe juht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "nr 917"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 6,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "aktiivsem osa"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suhe juht Sven Ratassepp"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "OTHER-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "milline piirang"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kallim hotell"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eestlane naasmine ol\u00fcmpialiikumine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 34,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eestlane naasmine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "balti riik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "abiline koostatud \u00fclevaade"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 26,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "NSV osav\u00f5tt"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma kaks"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Guinea vaene"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Balti regioon"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine poolaeg"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "see \u00fcmbrus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "muu saar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "h\u00e4\u00e4lteenamus konventsioon juht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 30,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "h\u00e4\u00e4lteenamus konventsioon"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "balti liiga"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "RE peadirektor"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "ORG-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "NSV osav\u00f5tt liige"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "ORG-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti P\u00e4evaleht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Ameerika miljon\u00e4r Gregg Bemis"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 29,
#               "labels": [
#                 "LOC-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Ameerika miljon\u00e4r"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "vene keel"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "vanem s\u00fcda"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "telefonih\u00e4\u00e4letus laekuma tulemus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 32,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine v\u00f5ti"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine liikmesriik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suurim pagulaskirjastus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "rikkam rokistaar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "laud paigutatud veinipakk"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eesti muusika"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Toomas Hendrik Ilves"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Tartu \u00dclikool"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Rootsi rannik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Guinea vaene eeslinn"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti osav\u00f5tt liige"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "LOC-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti osav\u00f5tt"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Telefon"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Briti advokaat Jonathan Faull"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 29,
#               "labels": [
#                 "LOC-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Briti advokaat"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1995. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine p\u00e4ev"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine pool"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine maailmas\u00f5da"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine koht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "soome pianist"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "politsei pressiesindaja"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "maitsvaim k\u00f5hut\u00e4ide"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "laevakere m\u00f5juma j\u00f5ud"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "komisjon moodustamine omavalitsus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 33,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "komisjon moodustamine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "keskerakondlane pooldav germanist"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 33,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "juhatus esimees"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eluv\u00f5imelisus hindamine P. Jaagosild"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 36,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eluv\u00f5imelisus hindamine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ametivisiit naasma Musharrafi"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 29,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "aasta s\u00fcndima vald"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "USA investeerimispank"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "RE peadirektor V\u00e4ino Viilupi"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 28,
#               "labels": [
#                 "ORG-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Paolo Maldini Milani"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Draamateater"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ERM2 liitumine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "t\u00f6\u00f6 \u00dcRO"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine lugemine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine kord"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine autok\u00fctus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine aste"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "riik oma"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "rekord A"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "rahvaste\u00fchendus t\u00f6\u00f6"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "prantsuse l\u00fctseum"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "pilt koosnev fotoalbum"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 22,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma viisk\u00fcmmend"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma poiss s\u00f5ber"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma poiss"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "muu vara"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "muu tingimus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "miski muu"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "mees arusaam prestii\u017e"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "mees arusaam"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "madalam tase"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kroon k\u00fc\u00fcndima kingitus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kaubaoptsioon seotud risk"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kapital p\u00f5hinev jaekaubanduskett"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 32,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "inglise keel"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "artikkel anal\u00fc\u00fcsitud t\u00f6\u00f6tav"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 27,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "aasta s\u00fcndima Oleg"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "USA investeerimispank Merrill Lynch"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 35,
#               "labels": [
#                 "LOC-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Riigikogu liige"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "ORG-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Kristjan Thor V\u00e4hi"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Halens Holding AB"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Suurperede"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Pank"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti NATO"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "LOC-ORG"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ERM2 liitumine eestvedaja"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Argentiina president"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "23aastane noor"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1999. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "\u00fchtne Venemaa"
#     },
#     "annotations": [
#       {
# ...
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "21. aprill"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20aastane Walker"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2006. aastal28"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2006. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2005. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2003. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2000. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20. september"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20. juuli"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20. jaanuar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1998. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1997. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1996. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1984. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1979. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1973. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1963. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1960. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1959. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1942. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1934. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "18. sajand"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "17silbiline l\u00fchivorm"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1776. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "170. muudatusettepanek"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 22,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "16x9 formaat"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "16. juuni"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "15. sajand"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "14protsendiline palgat\u00f5us"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "14aastane Kristjan"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "12aastane Alan"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1297. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "12. november"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "12. juuni"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "10. oktoober"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "10. jaanuar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "10. aprill"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "01. majandusaasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "terms",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   }
# ]

# %%
task.export_data(texts, file_path='label_studio_confs/export_str_3.json', indent=2)

# %%
conf2 = PhraseClassificationConfiguration(phrase_labels=['syntax_tree_pattern', 'POS_pattern', 'NER_pattern'], class_labels={'True': 'Jah', 'False': 'Ei'})
task2 = PhraseClassificationTask(conf2, input_layer='terms', output_layer='terms', label_attribute='NER_pattern')
print(task2.interface_file)
# Out:
# <View>
#   <Labels name="phrase" toName="text" >
#     <Label value="syntax_tree_pattern" background="#1b9e77" />
#     <Label value="POS_pattern" background="#d95f02" />
#     <Label value="NER_pattern" background="#7570b3" />
#   </Labels>
#   <Text name="text" value="$text" />
#   <Choices name="phrase_class" toName="text" >
#     <Choice value="Jah" alias="True" />
#     <Choice value="Ei" alias="False" />
#   </Choices>
# </View>

# %%
print(task2.export_data(texts[0], indent=2))
# Out:
# [
#   {
#     "data": {
#       "text": "Euroopa tunnetamine kodu"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "LOC-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   }
# ]
# C:\Users\liivas\Documents\Töö\test_100000_sentences\..\estnltk_patches\label_studio\labelling_tasks\phrase_classification_task.py:197: UserWarning:
# Unexpected label classes occurred during the export.
# Use the field exported_labels to see all class labels generated by the export
# and update the labelling configuration by calling set_class_labels(...)
#   warnings.warn(

# %%
print(task2.export_data(texts, indent=2))
# Out:
# [
#   {
#     "data": {
#       "text": "Euroopa tunnetamine kodu"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "LOC-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Euroopa tunnetamine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ca 5%"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 5,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Balti riik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "N\u00f5ukogu Liit"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "\u00dchendriik t\u00f6\u00f6stusspionaazh"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 26,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "t\u00f6\u00f6stusspionaazh Euroopa"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "elu seotud teema"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "riigikontroll kontroll pank"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 27,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "riigikontroll kontroll"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 22,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eesti keel"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Euroopa Liit"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suurim s\u00f5idukiirus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suhe juht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "nr 917"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 6,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "aktiivsem osa"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suhe juht Sven Ratassepp"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 24,
#               "labels": [
#                 "OTHER-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "milline piirang"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kallim hotell"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eestlane naasmine ol\u00fcmpialiikumine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 34,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eestlane naasmine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "balti riik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "abiline koostatud \u00fclevaade"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 26,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "NSV osav\u00f5tt"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma kaks"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Guinea vaene"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Balti regioon"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine poolaeg"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "see \u00fcmbrus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "muu saar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "h\u00e4\u00e4lteenamus konventsioon juht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 30,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "h\u00e4\u00e4lteenamus konventsioon"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "balti liiga"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "RE peadirektor"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "ORG-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "NSV osav\u00f5tt liige"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "ORG-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti P\u00e4evaleht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Ameerika miljon\u00e4r Gregg Bemis"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 29,
#               "labels": [
#                 "LOC-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Ameerika miljon\u00e4r"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "vene keel"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "vanem s\u00fcda"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "telefonih\u00e4\u00e4letus laekuma tulemus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 32,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine v\u00f5ti"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine liikmesriik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "suurim pagulaskirjastus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "rikkam rokistaar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "laud paigutatud veinipakk"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eesti muusika"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Toomas Hendrik Ilves"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Tartu \u00dclikool"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Rootsi rannik"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Guinea vaene eeslinn"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti osav\u00f5tt liige"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "LOC-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti osav\u00f5tt"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Telefon"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Briti advokaat Jonathan Faull"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 29,
#               "labels": [
#                 "LOC-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Briti advokaat"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1995. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine p\u00e4ev"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine pool"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine maailmas\u00f5da"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine koht"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "soome pianist"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "politsei pressiesindaja"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "maitsvaim k\u00f5hut\u00e4ide"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "laevakere m\u00f5juma j\u00f5ud"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "komisjon moodustamine omavalitsus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 33,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "komisjon moodustamine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "keskerakondlane pooldav germanist"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 33,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "juhatus esimees"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eluv\u00f5imelisus hindamine P. Jaagosild"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 36,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "eluv\u00f5imelisus hindamine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ametivisiit naasma Musharrafi"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 29,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "aasta s\u00fcndima vald"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "USA investeerimispank"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "RE peadirektor V\u00e4ino Viilupi"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 28,
#               "labels": [
#                 "ORG-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Paolo Maldini Milani"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Draamateater"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ERM2 liitumine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "t\u00f6\u00f6 \u00dcRO"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine lugemine"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine kord"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine autok\u00fctus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "teine aste"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "riik oma"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "rekord A"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "rahvaste\u00fchendus t\u00f6\u00f6"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 19,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "prantsuse l\u00fctseum"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "pilt koosnev fotoalbum"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 22,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma viisk\u00fcmmend"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma poiss s\u00f5ber"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "oma poiss"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "muu vara"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 8,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "muu tingimus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "miski muu"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "mees arusaam prestii\u017e"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 21,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "mees arusaam"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "madalam tase"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kroon k\u00fc\u00fcndima kingitus"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 23,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kaubaoptsioon seotud risk"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "kapital p\u00f5hinev jaekaubanduskett"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 32,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "inglise keel"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "artikkel anal\u00fc\u00fcsitud t\u00f6\u00f6tav"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 27,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "aasta s\u00fcndima Oleg"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "USA investeerimispank Merrill Lynch"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 35,
#               "labels": [
#                 "LOC-OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Riigikogu liige"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 15,
#               "labels": [
#                 "ORG-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Kristjan Thor V\u00e4hi"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Halens Holding AB"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Suurperede"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti Pank"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Eesti NATO"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "LOC-ORG"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "ERM2 liitumine eestvedaja"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "Argentiina president"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "LOC-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "23aastane noor"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1999. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
# ...
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "21. aprill"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20aastane Walker"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 16,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2006. aastal28"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2006. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2005. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2003. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "2000. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20. september"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 13,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20. juuli"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "20. jaanuar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1998. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1997. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1996. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1984. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1979. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1973. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1963. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1960. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1959. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1942. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1934. a"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 7,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "18. sajand"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "17silbiline l\u00fchivorm"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 20,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1776. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "170. muudatusettepanek"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 22,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "16x9 formaat"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "16. juuni"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "15. sajand"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "14protsendiline palgat\u00f5us"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 25,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "14aastane Kristjan"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 18,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "12aastane Alan"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 14,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "1297. aasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "12. november"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "12. juuni"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 9,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "10. oktoober"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 12,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "10. jaanuar"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 11,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "10. aprill"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 10,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "data": {
#       "text": "01. majandusaasta"
#     },
#     "annotations": [
#       {
#         "result": [
#           {
#             "value": {
#               "start": 0,
#               "end": 17,
#               "labels": [
#                 "OTHER-OTHER"
#               ]
#             },
#             "from_name": "phrase",
#             "to_name": "text",
#             "type": "labels"
#           }
#         ]
#       }
#     ]
#   }
# ]

# %%
task2.export_data(texts, file_path='label_studio_confs/export_str_4.json', indent=2)

# %%
conf3 = PhraseClassificationConfiguration(phrase_labels=['syntax_tree_pattern', 'POS_pattern', 'NER_pattern'], class_labels={'True': 'True', 'False': 'False'})
task3 = PhraseClassificationTask(conf3, input_layer='terms', output_layer='terms', label_attribute='NER_pattern', exported_meta_fields=['syntax_tree_pattern', 'POS_pattern', 'NER_pattern'])
print(task3.interface_file)
# Out:
# <View>
#   <Labels name="phrase" toName="text" >
#     <Label value="syntax_tree_pattern" background="#1b9e77" />
#     <Label value="POS_pattern" background="#d95f02" />
#     <Label value="NER_pattern" background="#7570b3" />
#   </Labels>
#   <Text name="text" value="$text" />
#   <Choices name="phrase_class" toName="text" >
#     <Choice value="True" alias="True" />
#     <Choice value="False" alias="False" />
#   </Choices>
# </View>

# %%
task3.export_data(texts, file_path='label_studio_confs/export_str_5.json', indent=2)
