# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### Phrase counts

# %%
con = sqlite3.connect("tagged_noun_phrases.db")
cur = con.cursor()

# %%
cur.execute("SELECT raw_text, count(*) FROM tagged_phrases GROUP BY raw_text ORDER BY count(*) DESC")
rows = cur.fetchall()

# %%
con.close()

# %%
data = {'count': [], 'phrase': []}
for row in rows:
    data['count'].append(row[1])
    data['phrase'].append(row[0])

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#       count                    phrase
# 0        32  Euroopa tunnetamine kodu
# 1        32       Euroopa tunnetamine
# 2        21                     ca 5%
# 3        19              Euroopa Liit
# 4        19                Balti riik
# ...     ...                       ...
# 2166      1            12aastane Alan
# 2167      1                 12. juuni
# 2168      1                 11. juuni
# 2169      1                 10. minut
# 2170      1       000kroonine alghind
#
# [2171 rows x 2 columns]

# %%
con = sqlite3.connect('tagged_noun_phrases.db')
cur = con.cursor()

df.to_sql('phrases_counts', con, if_exists='replace', index=False)
con.close()

# %% [markdown]
# ### Phrases with extraction and NER patterns

# %%
def get_extraction_pattern(con):
    cur = con.cursor()
    cur.execute("SELECT extraction_pattern, count(*) FROM tagged_phrases GROUP BY extraction_pattern ORDER BY count(*) DESC")
    
    rows = cur.fetchall()
    return rows

def get_patterns_ner(con):
    con.cursor()
    cur.execute("SELECT ner_pattern, count(*) FROM tagged_phrases GROUP BY ner_pattern ORDER BY count(*) DESC")
    
    rows = cur.fetchall()  
    return rows

def get_phrases(con):
    con.cursor()
    cur.execute("SELECT raw_text, count(*) FROM tagged_phrases GROUP BY raw_text ORDER BY count(*) DESC")
    
    rows = cur.fetchall()  
    return rows

# %%
con = sqlite3.connect('tagged_noun_phrases.db')
cur = con.cursor()

data = {'count': [], 'extraction_pattern': [], 'ner_pattern': [], 'phrase': []}
extraction_patterns = get_extraction_pattern(con)
patterns_ner = get_patterns_ner(con)
                                  
for pattern in extraction_patterns:
    for ner in patterns_ner:
        #cur.execute("SELECT * FROM tagged_phrases WHERE extraction_pattern = ? AND ner_pattern = ?", (pattern[0], ner[0]))
        #criteria_freq = len(cur.fetchall()) 
        
        cur.execute("SELECT raw_text, count(*) FROM tagged_phrases WHERE extraction_pattern = ? AND ner_pattern = ? GROUP BY raw_text ORDER BY count(*) DESC", (pattern[0], ner[0]))
        phrase_freqs = cur.fetchall()  
        
        for phrase in phrase_freqs:
            data['count'].append(phrase[1])
            data['extraction_pattern'].append(pattern[0])
            data['ner_pattern'].append(ner[0])
            data['phrase'].append(phrase[0])

# %%
con.close()

# %%
df2 = pd.DataFrame.from_dict(data)

# %%
df2
# Out:
#       count                extraction_pattern        ner_pattern  \
# 0        12             1 2 nmod,2 0 root,S-S        OTHER-OTHER
# 1        11             1 2 nmod,2 0 root,S-S        OTHER-OTHER
# 2        11             1 2 nmod,2 0 root,S-S        OTHER-OTHER
# 3         5             1 2 nmod,2 0 root,S-S        OTHER-OTHER
# 4         5             1 2 nmod,2 0 root,S-S        OTHER-OTHER
# ...     ...                               ...                ...
# 2177      1             1 2 amod,2 0 root,H-H        OTHER-OTHER
# 2178      1             1 2 amod,2 0 root,H-H        OTHER-OTHER
# 2179      2  1 0 root,2 1 flat,3 1 flat,Y-Y-S  OTHER-OTHER-OTHER
# 2180      1  1 0 root,2 1 flat,3 1 flat,S-S-Y  OTHER-OTHER-OTHER
# 2181      1  1 0 root,2 1 flat,3 1 flat,S-S-Y  OTHER-OTHER-OTHER
#
#                                 phrase
# 0            häälteenamus konventsioon
# 1                            suhe juht
# 2                    eestlane naasmine
# 3                      suu maigutamine
# 4               riigikontroll kontroll
# ...                                ...
# 2177                      Vaba Euroopa
# 2178  Rahvusvaheline Tööorganisatsioon
# 2179                         is in the
# 2180                      per ardua ad
# 2181                      don worry be
#
# [2182 rows x 4 columns]

# %%
# evidently, there are some phrases that occur with multiple extraction and/or NER patterns
len(df2['phrase'].unique())
# Out:
# 2171

# %%
df2 = df2.sort_values('phrase')

# %%
df2
# Out:
#       count                extraction_pattern        ner_pattern  \
# 1526      1             1 2 amod,2 0 root,A-S        OTHER-OTHER
# 1311      1             1 2 amod,2 0 root,O-S        OTHER-OTHER
# 1310      1             1 2 amod,2 0 root,O-S        OTHER-OTHER
# 1309      1             1 2 amod,2 0 root,O-S        OTHER-OTHER
# 1697      1             1 2 amod,2 0 root,A-H        OTHER-OTHER
# ...     ...                               ...                ...
# 578       1             1 2 nmod,2 0 root,Y-S        OTHER-OTHER
# 45        1             1 2 nmod,2 0 root,S-S        OTHER-OTHER
# 1803      1  1 2 nmod,2 0 root,3 2 nmod,S-S-H  OTHER-OTHER-OTHER
# 2127      1             1 2 nmod,2 0 root,H-N          LOC-OTHER
# 1846      1             1 2 amod,2 0 root,A-N        OTHER-OTHER
#
#                      phrase
# 1526    000kroonine alghind
# 1311              10. minut
# 1310              11. juuni
# 1309              12. juuni
# 1697         12aastane Alan
# ...                     ...
# 578           üx valgusfoor
# 45                 üür hind
# 1803  üür hind Draamateater
# 2127           Šveits kümme
# 1846     šŠikolenkole 66.92
#
# [2182 rows x 4 columns]

# %%
con = sqlite3.connect('tagged_noun_phrases.db')
cur = con.cursor()

df2.to_sql('phrases_patterns', con, if_exists='replace', index=False)
con.close()

# %% [markdown]
# ### Phrases with pattern context

# %%
con = sqlite3.connect('tagged_noun_phrases.db')
cur = con.cursor()

data = {'count': [], 'phrase': [], 'extraction_pattern': [], 'pat_%': [], 'ner_pattern': [], 'ner_%': []}
phrases = get_phrases(con)
                                  
for phrase in phrases:
    cur.execute("SELECT extraction_pattern, count(*) FROM tagged_phrases WHERE raw_text = ? GROUP BY extraction_pattern ORDER BY count(*) DESC", (phrase[0],))
    pattern_ex_freqs = cur.fetchall()
    for ex_pattern in pattern_ex_freqs:
        cur.execute("SELECT ner_pattern, count(*) FROM tagged_phrases WHERE raw_text = ? AND extraction_pattern = ? GROUP BY ner_pattern ORDER BY count(*) DESC", (phrase[0], ex_pattern[0]))
        pattern_ner_freqs = cur.fetchall()
            
        for ner_pattern in pattern_ner_freqs:
            data['count'].append(phrase[1])
            data['phrase'].append(phrase[0])
            data['extraction_pattern'].append(ex_pattern[0])
            # extraction pattern % of current phrase
            data['pat_%'].append(ex_pattern[1]/phrase[1])
            data['ner_pattern'].append(ner_pattern[0])
            # ner sequence % of current extraction pattern
            data['ner_%'].append(ner_pattern[1]/ex_pattern[1])

# %%
con.close()

# %%
df3 = pd.DataFrame.from_dict(data)

# %%
df3
# Out:
#       count                    phrase                extraction_pattern  \
# 0        32  Euroopa tunnetamine kodu  1 2 nmod,2 0 root,3 2 nmod,H-S-S
# 1        32       Euroopa tunnetamine             1 2 nmod,2 0 root,H-S
# 2        21                     ca 5%             1 2 nmod,2 0 root,Y-N
# 3        19              Euroopa Liit             1 2 nmod,2 0 root,H-H
# 4        19                Balti riik             1 2 amod,2 0 root,H-S
# ...     ...                       ...                               ...
# 2177      1            12aastane Alan             1 2 amod,2 0 root,A-H
# 2178      1                 12. juuni             1 2 amod,2 0 root,O-S
# 2179      1                 11. juuni             1 2 amod,2 0 root,O-S
# 2180      1                 10. minut             1 2 amod,2 0 root,O-S
# 2181      1       000kroonine alghind             1 2 amod,2 0 root,A-S
#
#       pat_%      ner_pattern  ner_%
# 0       1.0  LOC-OTHER-OTHER    1.0
# 1       1.0        LOC-OTHER    1.0
# 2       1.0      OTHER-OTHER    1.0
# 3       1.0      OTHER-OTHER    1.0
# 4       1.0      OTHER-OTHER    1.0
# ...     ...              ...    ...
# 2177    1.0      OTHER-OTHER    1.0
# 2178    1.0      OTHER-OTHER    1.0
# 2179    1.0      OTHER-OTHER    1.0
# 2180    1.0      OTHER-OTHER    1.0
# 2181    1.0      OTHER-OTHER    1.0
#
# [2182 rows x 6 columns]

# %%
con = sqlite3.connect('tagged_noun_phrases.db')
cur = con.cursor()

df3.to_sql('phrases_context', con, if_exists='replace', index=False) # writes to file
con.close()
