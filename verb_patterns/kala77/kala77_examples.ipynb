# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # kala77 baasist päringute tegemine, näidete otsimine

# %%
import os
import sys
from pathlib import Path
from kala77_helpers import *

ROOT = str(Path(os.getcwd()).parent.parent)
sys.path.append(f"{ROOT}/apriori/v33")

from V33Apriori import V33

KALA77_DB = (
   os.getcwd()+"/kala77.db"
)

# %%
kala77 = V33(file_path=KALA77_DB)

# %%
# %%time
import pandas as pd
phrases = kala77.get_phrases(verb='saama', verb_compound='')
df = pd.DataFrame.from_dict(phrases)
#df.to_csv('fraasid.csv', index=None)
print(df.shape[0])
df.head()
# Out:
# 994101
# CPU times: user 3.61 s, sys: 1.19 s, total: 4.8 s
# Wall time: 15.9 s
#    head_id  loc                         phrase  sentence_id
# 0       44    2                           saan           34
# 1       74    4  sa ei saa toidupoest soovitut           50
# 2       96    3       Ma ei saa aru inimestest           63
# 3      130    1                    Saime kirju           81
# 4      139   28                            saa           83

# %%
# %%time
kala77.make_all(verb='saama', verb_compound='')
# Out:
# ************************************************ saama   ************************************************
# Ridu analüüsimiseks: 502595
# 	liiga palju ridu analüüsimiseks: 502595
# 	analüüsitakse 100000 juhuslikku
# apriori min_support: 0.05
# delta: 0.03
# percent: 50
#     support                                          itemlists   drop  \
# 4   0.63487                                 [(NSUBJ, nom, , )]  False
# 7   0.35765                                  [(OBJ, part, , )]  False
# 1   0.33563                                   [(ADVMOD, , , )]  False
# 5   0.25833                                   [(OBJ, gen, , )]  False
# 24  0.21917                [(NSUBJ, nom, , ), (OBJ, part, , )]  False
# 16  0.20527                 [(NSUBJ, nom, , ), (ADVMOD, , , )]  False
# 9   0.18203                                    [(OBL, el, , )]  False
# 23  0.16607                 [(NSUBJ, nom, , ), (OBJ, gen, , )]  False
# 3   0.14180                                    [(AUX, , ei, )]  False
# 18  0.13183                  [(OBJ, part, , ), (ADVMOD, , , )]  False
# 26  0.13055                  [(NSUBJ, nom, , ), (OBL, el, , )]  False
# 0   0.11838                                    [(ADVCL, , , )]  False
# 8   0.10899                                    [(OBL, ad, , )]  False
# 10  0.09174                                    [(OBL, in, , )]  False
# 22  0.08778                   [(OBJ, part, , ), (AUX, , ei, )]   True
# 21  0.08681                  [(NSUBJ, nom, , ), (AUX, , ei, )]   True
# 2   0.08151                                      [(AUX, , , )]   True
# 29  0.08146  [(NSUBJ, nom, , ), (OBJ, part, , ), (ADVMOD, ,...  False
# 13  0.07806                  [(NSUBJ, nom, , ), (ADVCL, , , )]  False
# 25  0.07420                  [(NSUBJ, nom, , ), (OBL, ad, , )]  False
# 28  0.07040                   [(OBJ, part, , ), (OBL, el, , )]  False
# 17  0.06348                   [(OBJ, gen, , ), (ADVMOD, , , )]  False
# 27  0.06023                  [(NSUBJ, nom, , ), (OBL, in, , )]  False
# 20  0.06011                    [(NSUBJ, nom, , ), (AUX, , , )]  False
# 15  0.05947                    [(ADVMOD, , , ), (AUX, , ei, )]  False
# 14  0.05910                   [(OBJ, part, , ), (ADVCL, , , )]  False
# 30  0.05908  [(NSUBJ, nom, , ), (OBJ, part, , ), (AUX, , ei...  False
# 11  0.05888                                   [(OBL, kom, , )]  False
# 19  0.05633                    [(OBL, el, , ), (ADVMOD, , , )]  False
# 6   0.05351                                   [(OBJ, nom, , )]  False
# 12  0.05046                    [(ADVMOD, , , ), (ADVCL, , , )]  False
#
#                                           drop_reason  length
# 4                                                           1
# 7                                                           1
# 1                                                           1
# 5                                                           1
# 24                                                          2
# 16                                                          2
# 9                                                           1
# 23                                                          2
# 3                                                           1
# 18                                                          2
# 26                                                          2
# 0                                                           1
# 8                                                           1
# 10                                                          1
# 22  (row 30) delta: abs(0.0591 - 0.0878) < 0.03 %:...       2
# 21  (row 30) delta: abs(0.0591 - 0.0868) < 0.03 %:...       2
# 2   (row 20) delta: abs(0.0601 - 0.0815) < 0.03 %:...       1
# 29                                                          3
# 13                                                          2
# 25                                                          2
# 28                                                          2
# 17                                                          2
# 27                                                          2
# 20                                                          2
# 15                                                          2
# 14                                                          2
# 30                                                          3
# 11                                                          1
# 19                                                          2
# 6                                                           1
# 12                                                          2
# CPU times: user 12.2 s, sys: 2.32 s, total: 14.5 s
# Wall time: 21.1 s

# %%
kala77._conn.close()
