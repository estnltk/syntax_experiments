# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # kala77 baasist päringute tegemine, näidete otsimine

# %%
import sys
sys.path.append('../../common_code')
from paths import PATH_ROOT

from kala77_helpers import *

from apriori import V33

KALA77_DB = (
   PATH_ROOT+"/databases/kala77.db"
)

# %%
kala77 = V33(file_path=KALA77_DB)

# %%
# %%time
import pandas as pd
phrases = kala77.get_phrases(verb='saama', verb_compound='')
df = pd.DataFrame.from_dict(phrases)
#df.to_csv('fraasid.csv', index=None)
print(df.shape[0])
df.head()
# Out:
# 994101
# CPU times: user 4.75 s, sys: 1.3 s, total: 6.05 s
# Wall time: 18.8 s
#    head_id  loc                         phrase  sentence_id
# 0       44    2                           saan           34
# 1       74    4  sa ei saa toidupoest soovitut           50
# 2       96    3       Ma ei saa aru inimestest           63
# 3      130    1                    Saime kirju           81
# 4      139   28                            saa           83

# %%
# %%time
kala77.make_all(verb='saama', verb_compound='')
# Out:
# ************************************************ saama   ************************************************
# Ridu analüüsimiseks: 502595
# 	liiga palju ridu analüüsimiseks: 502595
# 	analüüsitakse 100000 juhuslikku
# apriori min_support: 0.05
# delta: 0.03
# percent: 50
#     support                                          itemlists   drop  \
# 4   0.63609                                 [(NSUBJ, nom, , )]  False
# 7   0.35937                                  [(OBJ, part, , )]  False
# 1   0.33856                                   [(ADVMOD, , , )]  False
# 5   0.25843                                   [(OBJ, gen, , )]  False
# 24  0.22070                [(NSUBJ, nom, , ), (OBJ, part, , )]  False
# 16  0.20749                 [(NSUBJ, nom, , ), (ADVMOD, , , )]  False
# 9   0.17908                                    [(OBL, el, , )]  False
# 23  0.16641                 [(NSUBJ, nom, , ), (OBJ, gen, , )]  False
# 3   0.14171                                    [(AUX, , ei, )]  False
# 18  0.13551                  [(OBJ, part, , ), (ADVMOD, , , )]  False
# 26  0.12944                  [(NSUBJ, nom, , ), (OBL, el, , )]  False
# 0   0.11761                                    [(ADVCL, , , )]  False
# 8   0.11065                                    [(OBL, ad, , )]  False
# 10  0.09030                                    [(OBL, in, , )]  False
# 22  0.08785                   [(OBJ, part, , ), (AUX, , ei, )]   True
# 21  0.08758                  [(NSUBJ, nom, , ), (AUX, , ei, )]   True
# 29  0.08377  [(NSUBJ, nom, , ), (OBJ, part, , ), (ADVMOD, ,...  False
# 2   0.08092                                      [(AUX, , , )]   True
# 13  0.07666                  [(NSUBJ, nom, , ), (ADVCL, , , )]  False
# 25  0.07516                  [(NSUBJ, nom, , ), (OBL, ad, , )]  False
# 28  0.06958                   [(OBJ, part, , ), (OBL, el, , )]  False
# 17  0.06306                   [(OBJ, gen, , ), (ADVMOD, , , )]  False
# 11  0.05992                                   [(OBL, kom, , )]  False
# 15  0.05958                    [(ADVMOD, , , ), (AUX, , ei, )]  False
# 20  0.05957                    [(NSUBJ, nom, , ), (AUX, , , )]  False
# 30  0.05926  [(NSUBJ, nom, , ), (OBJ, part, , ), (AUX, , ei...  False
# 27  0.05915                  [(NSUBJ, nom, , ), (OBL, in, , )]  False
# 14  0.05862                   [(OBJ, part, , ), (ADVCL, , , )]  False
# 19  0.05627                    [(OBL, el, , ), (ADVMOD, , , )]  False
# 6   0.05466                                   [(OBJ, nom, , )]  False
# 12  0.05178                    [(ADVMOD, , , ), (ADVCL, , , )]  False
#
#                                           drop_reason  length
# 4                                                           1
# 7                                                           1
# 1                                                           1
# 5                                                           1
# 24                                                          2
# 16                                                          2
# 9                                                           1
# 23                                                          2
# 3                                                           1
# 18                                                          2
# 26                                                          2
# 0                                                           1
# 8                                                           1
# 10                                                          1
# 22  (row 30) delta: abs(0.0593 - 0.0878) < 0.03 %:...       2
# 21  (row 30) delta: abs(0.0593 - 0.0876) < 0.03 %:...       2
# 29                                                          3
# 2   (row 20) delta: abs(0.0596 - 0.0809) < 0.03 %:...       1
# 13                                                          2
# 25                                                          2
# 28                                                          2
# 17                                                          2
# 11                                                          1
# 15                                                          2
# 20                                                          2
# 30                                                          3
# 27                                                          2
# 14                                                          2
# 19                                                          2
# 6                                                           1
# 12                                                          2
# CPU times: user 17.2 s, sys: 2.81 s, total: 20 s
# Wall time: 36 s

# %%
kala77._conn.close()
