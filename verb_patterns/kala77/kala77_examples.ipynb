# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # kala77 baasist päringute tegemine, näidete otsimine

# %%
import os
import sys
from pathlib import Path
from kala77_helpers import *

ROOT = str(Path(os.getcwd()).parent.parent)
sys.path.append(f"{ROOT}/apriori/v33")

from V33Apriori import V33

KALA77_DB = (
   os.getcwd()+"/kala77.db"
)

# %%
kala77 = V33(file_path=KALA77_DB)

# %%
# %%time
import pandas as pd
phrases = kala77.get_phrases(verb='varastama', verb_compound='')
df = pd.DataFrame.from_dict(phrases).head(10)
df.to_csv('fraasid.csv', index=None)
# Out:
# CPU times: user 412 ms, sys: 660 ms, total: 1.07 s
# Wall time: 7.6 s

# %%
kala77.make_all(verb='saama', verb_compound=None)
# Out:
# ************************************************ saama  None ************************************************
# Ridu analüüsimiseks: 522272
# 	liiga palju ridu analüüsimiseks: 522272
# 	analüüsitakse 100000 juhuslikku
# apriori min_support: 0.05
# delta: 0.03
# percent: 50
#     support                                          itemlists   drop  \
# 4   0.63340                                 [(NSUBJ, nom, , )]  False
# 7   0.35234                                  [(OBJ, part, , )]  False
# 1   0.33968                                   [(ADVMOD, , , )]  False
# 5   0.25077                                   [(OBJ, gen, , )]  False
# 24  0.21458                [(NSUBJ, nom, , ), (OBJ, part, , )]  False
# 16  0.20501                 [(NSUBJ, nom, , ), (ADVMOD, , , )]  False
# 9   0.17595                                    [(OBL, el, , )]  False
# 23  0.16103                 [(NSUBJ, nom, , ), (OBJ, gen, , )]  False
# 3   0.14266                                    [(AUX, , ei, )]  False
# 18  0.13118                  [(OBJ, part, , ), (ADVMOD, , , )]  False
# 26  0.12657                  [(NSUBJ, nom, , ), (OBL, el, , )]  False
# 0   0.11705                                    [(ADVCL, , , )]  False
# 8   0.10880                                    [(OBL, ad, , )]  False
# 10  0.09139                                    [(OBL, in, , )]  False
# 21  0.08836                  [(NSUBJ, nom, , ), (AUX, , ei, )]  False
# 22  0.08615                   [(OBJ, part, , ), (AUX, , ei, )]   True
# 2   0.08161                                      [(AUX, , , )]   True
# 29  0.07877  [(NSUBJ, nom, , ), (OBJ, part, , ), (ADVMOD, ,...  False
# 13  0.07612                  [(NSUBJ, nom, , ), (ADVCL, , , )]  False
# 25  0.07437                  [(NSUBJ, nom, , ), (OBL, ad, , )]  False
# 28  0.06739                   [(OBJ, part, , ), (OBL, el, , )]  False
# 17  0.06166                   [(OBJ, gen, , ), (ADVMOD, , , )]  False
# 15  0.05967                    [(ADVMOD, , , ), (AUX, , ei, )]  False
# 20  0.05958                    [(NSUBJ, nom, , ), (AUX, , , )]  False
# 27  0.05945                  [(NSUBJ, nom, , ), (OBL, in, , )]  False
# 11  0.05914                                   [(OBL, kom, , )]  False
# 30  0.05814  [(NSUBJ, nom, , ), (OBJ, part, , ), (AUX, , ei...  False
# 14  0.05811                   [(OBJ, part, , ), (ADVCL, , , )]  False
# 6   0.05520                                   [(OBJ, nom, , )]  False
# 19  0.05519                    [(OBL, el, , ), (ADVMOD, , , )]  False
# 12  0.05187                    [(ADVMOD, , , ), (ADVCL, , , )]  False
#
#                                           drop_reason  length
# 4                                                           1
# 7                                                           1
# 1                                                           1
# 5                                                           1
# 24                                                          2
# 16                                                          2
# 9                                                           1
# 23                                                          2
# 3                                                           1
# 18                                                          2
# 26                                                          2
# 0                                                           1
# 8                                                           1
# 10                                                          1
# 21                                                          2
# 22  (row 30) delta: abs(0.0581 - 0.0862) < 0.03 %:...       2
# 2   (row 20) delta: abs(0.0596 - 0.0816) < 0.03 %:...       1
# 29                                                          3
# 13                                                          2
# 25                                                          2
# 28                                                          2
# 17                                                          2
# 15                                                          2
# 20                                                          2
# 27                                                          2
# 11                                                          1
# 30                                                          3
# 14                                                          2
# 6                                                           1
# 19                                                          2
# 12                                                          2

# %%
#kala77._conn.close()
